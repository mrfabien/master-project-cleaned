# %%
import os
import sys
import glob
import xarray as xr
import numpy as np
from scipy.stats import genextreme, weibull_min
from joblib import Parallel, delayed
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.distributions.empirical_distribution import ECDF

operating_system = 'mac'

if operating_system == 'win':
    os.chdir('C:/Users/fabau/OneDrive/Documents/GitHub/master-project-cleaned/')
elif operating_system == 'curnagl':
    os.chdir('/work/FAC/FGSE/IDYST/tbeucler/default/fabien/repos/cleaner_version/')
else:
    os.chdir('/Users/fabienaugsburger/Documents/GitHub/master-project-cleaned/')

# Add the path to the custom library
custom_library_path = os.path.abspath('util/processing/')
sys.path.append(custom_library_path)

import time_series

custom_library_path_2 = os.path.abspath('util/gev')
sys.path.append(custom_library_path_2)

import data_processing
from data_processing import depickle, save_to_pickle

# %%
# TAKES 17 MINUTES TO RUN
without_storms = ''

def initialize_datasets_winter(months, days):
    datasets_winter = []
    for month in months:
        for day in days:
            try:
                dataset = depickle(f'data/climatology/daily_winter_season{without_storms}/climatology_europe_winter_{month}_{day}.pkl')
                datasets_winter.append(dataset)
            except FileNotFoundError:
                print(f'No data for month {month} and day {day}')
    return datasets_winter

def process_storm_file(event, cluster_data_original, datasets_winter, tif_15):
    print(f"Processing event: {event}")
    
    # Storm data
    storm = data_processing.process_daily_climatology(
        f'data/time_series_rasters_storms_15h/{event}.tif', 
        cluster_data_original, 
        event
    )
    
    clusters = range(0, 15)
    log_cdf_max = pd.DataFrame()
    
    for cluster_n in clusters:
        dataset_wind_speed = []
        for dataset in datasets_winter:
            for ds in dataset:
                ds_cluster = ds.where(tif_15['band_data'] == cluster_n)
                daily_max = ds_cluster['i10fg'].max().values
                dataset_wind_speed.append(daily_max)
                
        technic = genextreme
        # Fit the GEV distribution
        shape, loc, scale = technic.fit(dataset_wind_speed)
        storm_subset = storm[storm['cluster_n'] == cluster_n]['wind_speed_None']
        max_storm = storm_subset.max()
        # Compute return period for max_storm
        cdf_max_storm = technic.cdf(max_storm, shape, loc=loc, scale=scale)
        return_period = round((1 / (1 - cdf_max_storm)) / 2, 2)
        log_cdf_max_storm = -np.log(1 - cdf_max_storm)
        log_cdf_max.at[event, f'cluster_{cluster_n}'] = log_cdf_max_storm
        print(f"Return Period of Max {event} Wind Gust: {return_period:.2f} years for cluster {cluster_n}")

        x_vals = np.linspace(min(dataset_wind_speed), max(dataset_wind_speed), 1000)
        cdf_vals = technic.cdf(x_vals, shape, loc=loc, scale=scale)

        # Transform CDF to -log10(1-CDF)
        cdf_vals_transformed = -np.log10(1 - cdf_vals)

        # save both in CDF and transformed CDF folders
        pd.DataFrame(cdf_vals).to_csv(f'data/climatology_dm_winter_per_cluster{without_storms}/GEV_CDF/GEV_CDF_cluster_{cluster_n}.csv')
        pd.DataFrame(cdf_vals_transformed).to_csv(f'data/climatology_dm_winter_per_cluster{without_storms}/GEV_CDF_transformed/GEV_CDF_cluster_{cluster_n}.csv')

        # calculate the ECDF of the data
        ecdf = ECDF(dataset_wind_speed)

        # save the ECDF
        pd.DataFrame(ecdf.y).to_csv(f'data/climatology_dm_winter_per_cluster{without_storms}/ECDF/ECDF_cluster_{cluster_n}.csv')

        # save the dataset_wind_speed
        pd.DataFrame(dataset_wind_speed).to_csv(f'data/climatology_dm_winter_per_cluster{without_storms}/wind_data_cluster_{cluster_n}.csv')

        # Optional: Plot the transformed CDF
        # plt.plot(x_vals, cdf_vals_transformed, label="GEV Transformed CDF (-log10(1-CDF)")

    return log_cdf_max

def main_joblib_parallel_processing(path, cluster_csv, months, days, tif_15, n_jobs=-1):
    # Collect all storm files
    files = glob.glob(os.path.join(path, '*.tif'))
    name_tif = [os.path.basename(file) for file in files]
    # Remove 'max_all_storms.tif'
    if 'max_all_storms.tif' in name_tif:
        name_tif.remove('max_all_storms.tif')

    # Load cluster data
    cluster_data_original = pd.read_csv(cluster_csv)

    # Initialize datasets_winter
    datasets_winter = initialize_datasets_winter(months, days)

    # Run tasks in parallel using joblib
    results = Parallel(n_jobs=n_jobs)(
        delayed(process_storm_file)(file.split('.')[0], cluster_data_original, datasets_winter, tif_15) 
        for file in name_tif
    )
    
    # Combine results
    log_cdf_max_combined = pd.concat(results)
    return log_cdf_max_combined

# Prepare data for processing
tif_15 = xr.open_dataset('pre_processing/cluster/number_of_clusters/cleaned_cluster_15_v1.tif', engine='rasterio')
tif_15 = tif_15.rename({'x': 'longitude', 'y': 'latitude'})

path = '/Users/fabienaugsburger/Documents/GitHub/master-project-cleaned/data/time_series_rasters_storms_15h/'
cluster_csv = 'pre_processing/cluster/number_of_clusters/cleaned_cluster_15_v1.csv'
months = [10, 11, 12, 1, 2, 3]  # Winter months
days = range(1, 32)  # Days from 01 to 31

# Process all storms in parallel
log_cdf_max_combined = main_joblib_parallel_processing(path, cluster_csv, months, days, tif_15, n_jobs=-1)
# Out:
# No data for month 11 and day 31
# No data for month 2 and day 30
# No data for month 2 and day 31
# Processing event: 9_C3S_STORM_TRACKS_ERA5
# Processing event: 35_C3S_STORM_TRACKS_ERA5
# Return Period of Max 9_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.22 years for cluster 0
# Processing event: 82_C3S_STORM_TRACKS_ERA5
# Return Period of Max 35_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.56 years for cluster 0
# Return Period of Max 9_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.75 years for cluster 1
# Processing event: 1_C3S_STORM_TRACKS_ERA5
# Return Period of Max 35_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.02 years for cluster 1
# Return Period of Max 9_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.73 years for cluster 2
# Return Period of Max 82_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.84 years for cluster 0
# Processing event: 13_C3S_STORM_TRACKS_ERA5
# Return Period of Max 9_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.46 years for cluster 3
# Return Period of Max 35_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.40 years for cluster 2
# Return Period of Max 82_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.94 years for cluster 1
# Return Period of Max 1_C3S_STORM_TRACKS_ERA5 Wind Gust: 5.41 years for cluster 0
# Return Period of Max 9_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.01 years for cluster 4
# Return Period of Max 35_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.02 years for cluster 3
# Processing event: 95_AIDEN
# Return Period of Max 82_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.27 years for cluster 2
# Return Period of Max 1_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.84 years for cluster 1
# Return Period of Max 13_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.72 years for cluster 0
# Return Period of Max 35_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.14 years for cluster 4
# Return Period of Max 9_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.10 years for cluster 5
# Return Period of Max 82_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.92 years for cluster 3
# Processing event: 7_HERTA
# Return Period of Max 1_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.36 years for cluster 2
# Return Period of Max 13_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.54 years for cluster 1
# Return Period of Max 9_C3S_STORM_TRACKS_ERA5 Wind Gust: 95.08 years for cluster 6
# Return Period of Max 35_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.75 years for cluster 5
# Return Period of Max 95_AIDEN  Wind Gust: 0.54 years for cluster 0
# Return Period of Max 82_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.17 years for cluster 4
# Return Period of Max 1_C3S_STORM_TRACKS_ERA5 Wind Gust: 10.95 years for cluster 3
# Return Period of Max 13_C3S_STORM_TRACKS_ERA5 Wind Gust: 5.47 years for cluster 2
# Processing event: 28_C3S_STORM_TRACKS_ERA5
# Return Period of Max 9_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.03 years for cluster 7
# Return Period of Max 35_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.13 years for cluster 6
# Return Period of Max 95_AIDEN  Wind Gust: 1.00 years for cluster 1
# Return Period of Max 7_HERTA Wind Gust: 1.61 years for cluster 0
# Return Period of Max 82_C3S_STORM_TRACKS_ERA5 Wind Gust: 5.72 years for cluster 5
# Return Period of Max 1_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.74 years for cluster 4
# Return Period of Max 13_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.55 years for cluster 3
# Return Period of Max 9_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.60 years for cluster 8
# Return Period of Max 35_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.69 years for cluster 7
# Return Period of Max 95_AIDEN  Wind Gust: 0.75 years for cluster 2
# Return Period of Max 82_C3S_STORM_TRACKS_ERA5 Wind Gust:
# Return Period of Max 1_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.92 years for cluster 14
# Return Period of Max 13_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.57 years for cluster 13
# Return Period of Max 28_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.71 years for cluster 9
# Return Period of Max 79_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.62 years for cluster 5
# Return Period of Max 92_CIARA2 Wind Gust: 1.24 years for cluster 7
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 6.84 years for cluster 0
# Return Period of Max 7_HERTA Wind Gust: 0.99 years for cluster 10
# Processing event: 57_C3S_STORM_TRACKS_ERA5
# Return Period of Max 95_AIDEN  Wind Gust: 0.96 years for cluster 12
# Return Period of Max 13_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.54 years for cluster 14
# Return Period of Max 28_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.82 years for cluster 10
# Return Period of Max 92_CIARA2 Wind Gust: 0.99 years for cluster 8
# Return Period of Max 79_C3S_STORM_TRACKS_ERA5 Wind Gust: 178.21 years for cluster 6
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.10 years for cluster 1
# Return Period of Max 7_HERTA Wind Gust: 3.48 years for cluster 11
# Return Period of Max 95_AIDEN  Wind Gust: 0.53 years for cluster 13
# Return Period of Max 28_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.91 years for cluster 11
# Return Period of Max 79_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.39 years for cluster 7
# Return Period of Max 92_CIARA2 Wind Gust: 0.62 years for cluster 9
# Return Period of Max 57_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.84 years for cluster 0
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 19.55 years for cluster 2
# Return Period of Max 7_HERTA Wind Gust: 1.69 years for cluster 12
# Processing event: 50_C3S_STORM_TRACKS_ERA5
# Return Period of Max 95_AIDEN  Wind Gust: 0.93 years for cluster 14
# Return Period of Max 28_C3S_STORM_TRACKS_ERA5 Wind Gust: 8.50 years for cluster 12
# Return Period of Max 79_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.39 years for cluster 8
# Return Period of Max 92_CIARA2 Wind Gust: 22.87 years for cluster 10
# Return Period of Max 57_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.61 years for cluster 1
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.60 years for cluster 3
# Return Period of Max 7_HERTA Wind Gust: 1.57 years for cluster 13
# Processing event: 90_C3S_STORM_TRACKS_ERA5
# Return Period of Max 92_CIARA2 Wind Gust: 3.24 years for cluster 11
# Return Period of Max 79_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.66 years for cluster 9
# Return Period of Max 50_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.97 years for cluster 0
# Return Period of Max 28_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.57 years for cluster 13
# Return Period of Max 7_HERTA Wind Gust: 17.06 years for cluster 14
# Return Period of Max 57_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.53 years for cluster 2
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 5.75 years for cluster 4
# Return Period of Max 92_CIARA2 Wind Gust: 36.62 years for cluster 12
# Return Period of Max 50_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.55 years for cluster 1
# Return Period of Max 79_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.55 years for cluster 10
# Return Period of Max 28_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.58 years for cluster 14
# Return Period of Max 57_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.23 years for cluster 3
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.53 years for cluster 5
# Return Period of Max 90_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.78 years for cluster 0
# Processing event: 27_C3S_STORM_TRACKS_ERA5
# Return Period of Max 79_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.22 years for cluster 11
# Return Period of Max 92_CIARA2 Wind Gust: 0.74 years for cluster 13
# Return Period of Max 50_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.57 years for cluster 2
# Return Period of Max 57_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.10 years for cluster 4
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 6.39 years for cluster 6
# Return Period of Max 90_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.67 years for cluster 1
# Return Period of Max 79_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.84 years for cluster 12
# Return Period of Max 92_CIARA2 Wind Gust: 1.53 years for cluster 14
# Return Period of Max 50_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.43 years for cluster 3
# Return Period of Max 57_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.53 years for cluster 5
# Processing event: 58_C3S_STORM_TRACKS_ERA5
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.55 years for cluster 7
# Return Period of Max 27_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.11 years for cluster 0
# Return Period of Max 90_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.14 years for cluster 2
# Return Period of Max 79_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.22 years for cluster 13
# Return Period of Max 50_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.69 years for cluster 4
# Return Period of Max 57_C3S_STORM_TRACKS_ERA5 Wind Gust: 24.66 years for cluster 6
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.44 years for cluster 8
# Return Period of Max 27_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.08 years for cluster 1
# Return Period of Max 90_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.99 years for cluster 3
# Return Period of Max 79_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.78 years for cluster 14
# Return Period of Max 58_C3S_STORM_TRACKS_ERA5 Wind Gust: 23.04 years for cluster 0
# Return Period of Max 50_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.52 years for cluster 5
# Return Period of Max 57_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.64 years for cluster 7
# Processing event: 76_C3S_STORM_TRACKS_ERA5
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.58 years for cluster 9
# Return Period of Max 27_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.52 years for cluster 2
# Return Period of Max 90_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.92 years for cluster 4
# Return Period of Max 58_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.92 years for cluster 1
# Return Period of Max 57_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.53 years for cluster 8
# Return Period of Max 50_C3S_STORM_TRACKS_ERA5 Wind Gust: 64.43 years for cluster 6
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.52 years for cluster 10
# Return Period of Max 90_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.52 years for cluster 5
# Processing event: 71_CHRISTIAN
# Return Period of Max 27_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.03 years for cluster 3
# Return Period of Max 76_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.81 years for cluster 0
# Return Period of Max 58_C3S_STORM_TRACKS_ERA5 Wind Gust: 5.38 years for cluster 2
# Return Period of Max 57_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.53 years for cluster 9
# Return Period of Max 50_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.53 years for cluster 7
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 746.12 years for cluster 11
# Return Period of Max 27_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.29 years for cluster 4
# Return Period of Max 90_C3S_STORM_TRACKS_ERA5 Wind Gust: 24.52 years for cluster 6
# Return Period of Max 76_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.07 years for cluster 1
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 386.95 years for cluster 12
# Return Period of Max 50_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.94 years for cluster 8
# Return Period of Max 58_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.73 years for cluster 3
# Return Period of Max 71_CHRISTIAN Wind Gust: 10.14 years for cluster 0
# Return Period of Max 57_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.52 years for cluster 10
# Return Period of Max 90_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.53 years for cluster 7
# Return Period of Max 27_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.61 years for cluster
# Return Period of Max 45_C3S_STORM_TRACKS_ERA5 Wind Gust: 6.37 years for cluster 6
# Return Period of Max 14_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.60 years for cluster 13
# Return Period of Max 63_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.39 years for cluster 11
# Processing event: 19_C3S_STORM_TRACKS_ERA5
# Return Period of Max 65_XYNTHIA Wind Gust: 0.97 years for cluster 0
# Return Period of Max 85_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.78 years for cluster 4
# Return Period of Max 6_WIEBKE Wind Gust: 1.27 years for cluster 2
# Return Period of Max 48_GERO Wind Gust: 0.50 years for cluster 9
# Return Period of Max 45_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.41 years for cluster 7
# Return Period of Max 63_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.26 years for cluster 12
# Return Period of Max 14_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.93 years for cluster 14
# Return Period of Max 65_XYNTHIA Wind Gust: 10.23 years for cluster 1
# Return Period of Max 85_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.54 years for cluster 5
# Return Period of Max 6_WIEBKE Wind Gust: 286.32 years for cluster 3
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 18.35 years for cluster 0
# Return Period of Max 48_GERO Wind Gust: 1.77 years for cluster 10
# Return Period of Max 45_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.16 years for cluster 8
# Processing event: 61_EMMA
# Return Period of Max 63_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.51 years for cluster 13
# Return Period of Max 65_XYNTHIA Wind Gust: 0.81 years for cluster 2
# Return Period of Max 85_C3S_STORM_TRACKS_ERA5 Wind Gust: 1867.28 years for cluster 6
# Return Period of Max 48_GERO Wind Gust: 4.19 years for cluster 11
# Return Period of Max 6_WIEBKE Wind Gust: 24.78 years for cluster 4
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 16.53 years for cluster 1
# Return Period of Max 45_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.62 years for cluster 9
# Return Period of Max 63_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.98 years for cluster 14
# Return Period of Max 85_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.77 years for cluster 7
# Return Period of Max 65_XYNTHIA Wind Gust: 44.22 years for cluster 3
# Return Period of Max 48_GERO Wind Gust: 4.19 years for cluster 12
# Return Period of Max 61_EMMA Wind Gust: 8.53 years for cluster 0
# Return Period of Max 6_WIEBKE Wind Gust: 41.40 years for cluster 5
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.15 years for cluster 2
# Return Period of Max 45_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.37 years for cluster 10
# Processing event: 80_C3S_STORM_TRACKS_ERA5
# Return Period of Max 85_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.51 years for cluster 8
# Return Period of Max 65_XYNTHIA Wind Gust: 1.10 years for cluster 4
# Return Period of Max 61_EMMA Wind Gust: 5.18 years for cluster 1
# Return Period of Max 48_GERO Wind Gust: 0.50 years for cluster 13
# Return Period of Max 6_WIEBKE Wind Gust: 10.65 years for cluster 6
# Return Period of Max 45_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.88 years for cluster 11
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 26.69 years for cluster 3
# Return Period of Max 85_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.54 years for cluster 9
# Return Period of Max 65_XYNTHIA Wind Gust: 1.53 years for cluster 5
# Return Period of Max 48_GERO Wind Gust: 0.68 years for cluster 14
# Return Period of Max 45_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.79 years for cluster 12
# Return Period of Max 6_WIEBKE Wind Gust: 5.46 years for cluster 7
# /Users/fabienaugsburger/anaconda3/envs/master/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Return Period of Max 61_EMMA Wind Gust: 0.69 years for cluster 2
# Return Period of Max 80_C3S_STORM_TRACKS_ERA5 Wind Gust: 20.46 years for cluster 0
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.23 years for cluster 4
# Processing event: 11_C3S_STORM_TRACKS_ERA5
# Return Period of Max 85_C3S_STORM_TRACKS_ERA5 Wind Gust: 9.84 years for cluster 10
# Return Period of Max 65_XYNTHIA Wind Gust: 4.27 years for cluster 6
# Return Period of Max 6_WIEBKE Wind Gust: 41.33 years for cluster 8
# Return Period of Max 80_C3S_STORM_TRACKS_ERA5 Wind Gust: 59.06 years for cluster 1
# Return Period of Max 45_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.68 years for cluster 13
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.96 years for cluster 5
# Return Period of Max 61_EMMA Wind Gust: 26.36 years for cluster 3
# Return Period of Max 85_C3S_STORM_TRACKS_ERA5 Wind Gust: 3591.98 years for cluster 11
# Return Period of Max 65_XYNTHIA Wind Gust: 4.44 years for cluster 7
# Return Period of Max 6_WIEBKE Wind Gust: 0.83 years for cluster 9
# Return Period of Max 45_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.45 years for cluster 14
# Return Period of Max 11_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.52 years for cluster 0
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 58.70 years for cluster 6
# Return Period of Max 61_EMMA Wind Gust: 0.94 years for cluster 4
# Return Period of Max 80_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.58 years for cluster 2
# Return Period of Max 85_C3S_STORM_TRACKS_ERA5 Wind Gust: 14481.63 years for cluster 12
# Return Period of Max 65_XYNTHIA Wind Gust: 1.30 years for cluster 8
# Return Period of Max 6_WIEBKE Wind Gust: 1.99 years for cluster 10
# Return Period of Max 11_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.61 years for cluster 1
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 5.03 years for cluster 7
# Return Period of Max 61_EMMA Wind Gust: 0.68 years for cluster 5
# Return Period of Max 80_C3S_STORM_TRACKS_ERA5 Wind Gust: 11.27 years for cluster 3
# Return Period of Max 85_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.53 years for cluster 13
# Return Period of Max 65_XYNTHIA Wind Gust: 623.75 years for cluster 9
# Processing event: 46_JEANETTE
# Return Period of Max 6_WIEBKE Wind Gust: 0.64 years for cluster 11
# Return Period of Max 11_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.16 years for cluster 2
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.67 years for cluster 8
# Return Period of Max 80_C3S_STORM_TRACKS_ERA5 Wind Gust: 13.54 years for cluster 4
# Return Period of Max 85_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.57 years for cluster 14
# Return Period of Max 61_EMMA Wind Gust: 15.80 years for cluster 6
# Return Period of Max 65_XYNTHIA Wind Gust: 0.79 years for cluster 10
# Return Period of Max 6_WIEBKE Wind Gust: 1.59 years for cluster 12
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.62 years for cluster 9
# Return Period of Max 80_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.35 years for cluster 5
# Return Period of Max 11_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.17 years for cluster 3
# Return Period of Max 61_EMMA Wind Gust: 2.40 years for cluster 7
# Return Period of Max 46_JEANETTE Wind Gust: 8.89 years for cluster 0
# Return Period of Max 65_XYNTHIA Wind Gust: 0.51 years for cluster 11
# Processing event: 66_C3S_STORM_TRACKS_ERA5
# Return Period of Max 6_WIEBKE Wind Gust: 1009.31 years for cluster 13
# Return Period of Max 11_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.54 years for cluster 4
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.08 years for cluster 10
# Return Period of Max 61_EMMA Wind Gust: 0.62 years for cluster 8
# Return Period of Max 80_C3S_STORM_TRACKS_ERA5 Wind Gust: 58.56 years for cluster 6
# Return Period of Max 46_JEANETTE Wind Gust: 13.94 years for cluster 1
# Return Period of Max 65_XYNTHIA Wind Gust: 0.53 years for cluster 12
# Return Period of Max 6_WIEBKE Wind Gust: 2.15 years for cluster 14
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.87 years for cluster 11
# Return Period of Max 61_EMMA Wind Gust: 0.51 years for cluster 9
# Return Period of Max 80_C3S_STORM_TRACKS_ERA5 Wind Gust: 36.88 years for cluster 7
# Return Period of Max 11_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.50 years for cluster 5
# Return Period of Max 66_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.99 years for cluster 0
# Return Period of Max 46_JEANETTE Wind Gust: 1.03 years for cluster 2
# Return Period of Max 65_XYNTHIA Wind Gust: 7.26 years for cluster 13
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.71 years for cluster 12
# Processing event: 3_C3S_STORM_TRACKS_ERA5
# Return Period of Max 80_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.87 years for cluster 8
# Return Period of Max 61_EMMA Wind Gust: 0.82 years for cluster 10
# Return Period of Max 11_C3S_STORM_TRACKS_ERA5 Wind Gust: 7.18 years for cluster 6
# Return Period of Max 66_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.00 years for cluster 1
# Return Period of Max 65_XYNTHIA Wind Gust: 1215.24 years for cluster 14
# Return Period of Max 46_JEANETTE Wind Gust: 30.08 years for cluster 3
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.86 years for cluster 13
# Return Period of Max 80_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.64 years for cluster 9
# Return Period of Max 61_EMMA Wind Gust: 1.03 years for cluster 11
# Return Period of Max 11_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.74 years for cluster 7
# Return Period of Max 46_JEANETTE Wind Gust: 1.66 years for cluster 4
# Return Period of Max 66_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.50 years for cluster 2
# Return Period of Max 3_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.83 years for cluster 0
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.13 years for cluster 14
# Processing event: 88_C3S_STORM_TRACKS_ERA5
# Return Period of Max 61_EMMA Wind Gust: 3.14 years for cluster 12
# Return Period of Max 11_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.51 years for cluster 8
# Return Period of Max 80_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.63 years for cluster 10
# Return Period of Max 46_JEANETTE Wind Gust: 0.78 years for cluster 5
# Return Period of Max 66_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.59 years for cluster 3
# Return Period of Max 3_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.44 years for cluster 1
# Return Period of Max 11_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.52 years for cluster 9
# Return Period of Max 80_C3S_STORM_TRACKS_ERA5 Wind Gust: 7.91 years for cluster 11
# Return Period of Max 61_EMMA Wind Gust: 0.65 years for cluster 13
# Return Period of Max 66_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.55 years for cluster 4
# Return Period of Max 46_JEANETTE Wind Gust: 21.13 years for cluster 6
# Processing event: 94_ALEX
# Return Period of Max 88_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.14 years for cluster 0
# Return Period of Max 3_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.36 years for cluster 2
# Return Period of Max 61_EMMA Wind Gust: 0.89 years for cluster 14
# Return Period of Max 80_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.98 years for cluster 12
# Return Period of Max 11_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.64 years for cluster
# Return Period of Max 3_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.55 years for cluster 12
# Return Period of Max 64_KLAUS Wind Gust: 1.88 years for cluster 4
# Return Period of Max 88_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.87 years for cluster 10
# Processing event: 25_C3S_STORM_TRACKS_ERA5
# Return Period of Max 37_ANATOL Wind Gust: 32.97 years for cluster 6
# Return Period of Max 22_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.46 years for cluster 1
# Return Period of Max 55_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.23 years for cluster 3
# Return Period of Max 94_ALEX Wind Gust: 1.18 years for cluster 9
# Return Period of Max 3_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.62 years for cluster 13
# Return Period of Max 88_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.28 years for cluster 11
# Return Period of Max 64_KLAUS Wind Gust: 0.75 years for cluster 5
# Return Period of Max 37_ANATOL Wind Gust: 1.38 years for cluster 7
# Return Period of Max 22_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.37 years for cluster 2
# Return Period of Max 3_C3S_STORM_TRACKS_ERA5 Wind Gust: 31.47 years for cluster 14
# Return Period of Max 55_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.32 years for cluster 4
# Return Period of Max 25_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.61 years for cluster 0
# Return Period of Max 94_ALEX Wind Gust: 0.63 years for cluster 10
# Return Period of Max 88_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.63 years for cluster 12
# Return Period of Max 64_KLAUS Wind Gust: 427.26 years for cluster 6
# Return Period of Max 37_ANATOL Wind Gust: 0.76 years for cluster 8
# Return Period of Max 22_C3S_STORM_TRACKS_ERA5 Wind Gust: 39.64 years for cluster 3
# Processing event: 52_C3S_STORM_TRACKS_ERA5
# Return Period of Max 94_ALEX Wind Gust: 2.88 years for cluster 11
# Return Period of Max 55_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.49 years for cluster 5
# Return Period of Max 25_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.92 years for cluster 1
# Return Period of Max 64_KLAUS Wind Gust: 14.15 years for cluster 7
# Return Period of Max 88_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.94 years for cluster 13
# Return Period of Max 37_ANATOL Wind Gust: 0.78 years for cluster 9
# Return Period of Max 22_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.68 years for cluster 4
# Return Period of Max 88_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.56 years for cluster 14
# Return Period of Max 64_KLAUS Wind Gust: 0.60 years for cluster 8
# Return Period of Max 94_ALEX Wind Gust: 1.55 years for cluster 12
# Return Period of Max 55_C3S_STORM_TRACKS_ERA5 Wind Gust: 38.88 years for cluster 6
# Return Period of Max 25_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.58 years for cluster 2
# Return Period of Max 37_ANATOL Wind Gust: 1.00 years for cluster 10
# Return Period of Max 52_C3S_STORM_TRACKS_ERA5 Wind Gust: 28.71 years for cluster 0
# Return Period of Max 22_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.51 years for cluster 5
# Return Period of Max 64_KLAUS Wind Gust: 62.91 years for cluster 9
# Return Period of Max 55_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.06 years for cluster 7
# Return Period of Max 94_ALEX Wind Gust: 0.73 years for cluster 13
# Return Period of Max 25_C3S_STORM_TRACKS_ERA5 Wind Gust: 5.52 years for cluster 3
# Return Period of Max 37_ANATOL Wind Gust: 2.05 years for cluster 11
# Return Period of Max 52_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.54 years for cluster 1
# Return Period of Max 22_C3S_STORM_TRACKS_ERA5 Wind Gust: 52.83 years for cluster 6
# Return Period of Max 55_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.79 years for cluster 8
# Return Period of Max 94_ALEX Wind Gust: 4.40 years for cluster 14
# Return Period of Max 64_KLAUS Wind Gust: 1.81 years for cluster 10
# Return Period of Max 25_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.72 years for cluster 4
# Processing event: 93_DENNIS
# Return Period of Max 37_ANATOL Wind Gust: 17.12 years for cluster 12
# Return Period of Max 52_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.19 years for cluster 2
# Return Period of Max 22_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.58 years for cluster 7
# Return Period of Max 55_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.61 years for cluster 9
# Return Period of Max 64_KLAUS Wind Gust: 1.58 years for cluster 11
# Return Period of Max 25_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.01 years for cluster 5
# Return Period of Max 37_ANATOL Wind Gust: 0.51 years for cluster 13
# Return Period of Max 22_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.51 years for cluster 8
# Return Period of Max 52_C3S_STORM_TRACKS_ERA5 Wind Gust: 9.02 years for cluster 3
# Return Period of Max 93_DENNIS Wind Gust: 6.37 years for cluster 0
# Processing event: 74_C3S_STORM_TRACKS_ERA5
# Return Period of Max 64_KLAUS Wind Gust: 0.99 years for cluster 12
# Return Period of Max 55_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.68 years for cluster 10
# Return Period of Max 37_ANATOL Wind Gust: 0.52 years for cluster 14
# Return Period of Max 25_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.66 years for cluster 6
# Return Period of Max 22_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.54 years for cluster 9
# Return Period of Max 52_C3S_STORM_TRACKS_ERA5 Wind Gust: 86.43 years for cluster 4
# Return Period of Max 93_DENNIS Wind Gust: 3.85 years for cluster 1
# Return Period of Max 64_KLAUS Wind Gust: 6.56 years for cluster 13
# Return Period of Max 55_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.45 years for cluster 11
# Return Period of Max 25_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.73 years for cluster 7
# Return Period of Max 74_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.86 years for cluster 0
# Return Period of Max 52_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.76 years for cluster 5
# Return Period of Max 22_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.06 years for cluster 10
# Return Period of Max 64_KLAUS Wind Gust: 14404.94 years for cluster 14
# Return Period of Max 55_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.43 years for cluster 12
# Return Period of Max 93_DENNIS Wind Gust: 3.36 years for cluster 2
# Return Period of Max 25_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.96 years for cluster 8
# Processing event: 4_C3S_STORM_TRACKS_ERA5
# Return Period of Max 74_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.58 years for cluster 1
# Return Period of Max 22_C3S_STORM_TRACKS_ERA5 Wind Gust: 9.97 years for cluster 11
# Return Period of Max 52_C3S_STORM_TRACKS_ERA5 Wind Gust: 65.08 years for cluster 6
# Return Period of Max 55_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.67 years for cluster 13
# Return Period of Max 93_DENNIS Wind Gust: 2.56 years for cluster 3
# Return Period of Max 25_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.24 years for cluster 9
# Return Period of Max 74_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.78 years for cluster 2
# Return Period of Max 52_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.50 years for cluster 7
# ...
# Return Period of Max 15_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.10 years for cluster 12
# Return Period of Max 26_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.54 years for cluster 4
# Return Period of Max 51_C3S_STORM_TRACKS_ERA5 Wind Gust: 10.01 years for cluster 6
# Return Period of Max 96_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.66 years for cluster 0
# Return Period of Max 77_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.08 years for cluster 8
# Return Period of Max 62_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.80 years for cluster 10
# Return Period of Max 78_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.84 years for cluster 2
# Processing event: 56_C3S_STORM_TRACKS_ERA5
# Return Period of Max 15_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.66 years for cluster 13
# Return Period of Max 51_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.51 years for cluster 7
# Return Period of Max 26_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.59 years for cluster 5
# Return Period of Max 62_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.78 years for cluster 11
# Return Period of Max 77_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.68 years for cluster 9
# Return Period of Max 96_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.67 years for cluster 1
# Return Period of Max 78_C3S_STORM_TRACKS_ERA5 Wind Gust: 9.50 years for cluster 3
# Return Period of Max 15_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.83 years for cluster 14
# Return Period of Max 51_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.59 years for cluster 8
# Return Period of Max 26_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.17 years for cluster 6
# Return Period of Max 62_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.09 years for cluster 12
# Return Period of Max 96_C3S_STORM_TRACKS_ERA5 Wind Gust: 32.77 years for cluster 2
# Return Period of Max 77_C3S_STORM_TRACKS_ERA5 Wind Gust: 42.41 years for cluster 10
# Return Period of Max 56_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.49 years for cluster 0
# Return Period of Max 78_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.77 years for cluster 4
# Processing event: 29_C3S_STORM_TRACKS_ERA5
# Return Period of Max 51_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.56 years for cluster 9
# Return Period of Max 26_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.54 years for cluster 7
# Return Period of Max 77_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.05 years for cluster 11
# Return Period of Max 62_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.92 years for cluster 13
# Return Period of Max 56_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.98 years for cluster 1
# Return Period of Max 96_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.52 years for cluster 3
# Return Period of Max 78_C3S_STORM_TRACKS_ERA5 Wind Gust: 5.67 years for cluster 5
# Return Period of Max 26_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.60 years for cluster 8
# Return Period of Max 51_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.44 years for cluster 10
# Return Period of Max 62_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.88 years for cluster 14
# Return Period of Max 77_C3S_STORM_TRACKS_ERA5 Wind Gust: 11.33 years for cluster 12
# Return Period of Max 96_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.83 years for cluster 4
# Return Period of Max 29_C3S_STORM_TRACKS_ERA5 Wind Gust: 13.91 years for cluster 0
# Return Period of Max 56_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.56 years for cluster 2
# Return Period of Max 78_C3S_STORM_TRACKS_ERA5 Wind Gust: 56.74 years for cluster 6
# Processing event: 2_DARIA
# Return Period of Max 51_C3S_STORM_TRACKS_ERA5 Wind Gust: 10.61 years for cluster 11
# Return Period of Max 26_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.52 years for cluster 9
# Return Period of Max 77_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.08 years for cluster 13
# Return Period of Max 29_C3S_STORM_TRACKS_ERA5 Wind Gust: 7.24 years for cluster 1
# Return Period of Max 96_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.91 years for cluster 5
# Return Period of Max 56_C3S_STORM_TRACKS_ERA5 Wind Gust: 41.29 years for cluster 3
# Return Period of Max 78_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.63 years for cluster 7
# Return Period of Max 51_C3S_STORM_TRACKS_ERA5 Wind Gust: 10.65 years for cluster 12
# Return Period of Max 77_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.57 years for cluster 14
# Return Period of Max 26_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.08 years for cluster 10
# Return Period of Max 2_DARIA Wind Gust: 260.57 years for cluster 0
# Return Period of Max 96_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.02 years for cluster 6
# Return Period of Max 29_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.88 years for cluster 2
# Return Period of Max 56_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.36 years for cluster 4
# Return Period of Max 78_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.93 years for cluster 8
# Processing event: 12_C3S_STORM_TRACKS_ERA5
# Return Period of Max 26_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.39 years for cluster 11
# Return Period of Max 51_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.00 years for cluster 13
# Return Period of Max 2_DARIA Wind Gust: 43.62 years for cluster 1
# Return Period of Max 78_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.48 years for cluster 9
# Return Period of Max 96_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.59 years for cluster 7
# Return Period of Max 29_C3S_STORM_TRACKS_ERA5 Wind Gust: 26.92 years for cluster 3
# Return Period of Max 56_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.71 years for cluster 5
# Return Period of Max 51_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.54 years for cluster 14
# Return Period of Max 26_C3S_STORM_TRACKS_ERA5 Wind Gust: 6.39 years for cluster 12
# Return Period of Max 2_DARIA Wind Gust: 1.22 years for cluster 2
# Return Period of Max 96_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.92 years for cluster 8
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.07 years for cluster 0
# Return Period of Max 29_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.75 years for cluster 4
# Return Period of Max 78_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.71 years for cluster 10
# Return Period of Max 56_C3S_STORM_TRACKS_ERA5 Wind Gust: 11.64 years for cluster 6
# Processing event: 36_XYLIA
# Return Period of Max 26_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.52 years for cluster 13
# Return Period of Max 96_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.52 years for cluster 9
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.66 years for cluster 1
# Return Period of Max 2_DARIA Wind Gust: 1027.02 years for cluster 3
# Return Period of Max 78_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.69 years for cluster 11
# Return Period of Max 56_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.16 years for cluster 7
# Return Period of Max 29_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.19 years for cluster 5
# Return Period of Max 26_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.51 years for cluster 14
# Return Period of Max 2_DARIA Wind Gust: 3.79 years for cluster 4
# Return Period of Max 78_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.99 years for cluster 12
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 14.81 years for cluster 2
# Return Period of Max 96_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.25 years for cluster 10
# Return Period of Max 56_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.02 years for cluster 8
# Return Period of Max 29_C3S_STORM_TRACKS_ERA5 Wind Gust: 32.13 years for cluster 6
# Return Period of Max 36_XYLIA Wind Gust: 39.50 years for cluster 0
# Processing event: 73_XAVER
# Return Period of Max 96_C3S_STORM_TRACKS_ERA5 Wind Gust: 45.73 years for cluster 11
# Return Period of Max 2_DARIA Wind Gust: 0.75 years for cluster 5
# Return Period of Max 78_C3S_STORM_TRACKS_ERA5 Wind Gust: 7.11 years for cluster 13
# Return Period of Max 56_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.94 years for cluster 9
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 5.35 years for cluster 3
# Return Period of Max 36_XYLIA Wind Gust: 2.70 years for cluster 1
# Return Period of Max 29_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.19 years for cluster 7
# Return Period of Max 96_C3S_STORM_TRACKS_ERA5 Wind Gust: 66.93 years for cluster 12
# Return Period of Max 78_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.43 years for cluster 14
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.37 years for cluster 4
# Return Period of Max 2_DARIA Wind Gust: 177.72 years for cluster 6
# Return Period of Max 73_XAVER Wind Gust: 225.40 years for cluster 0
# Return Period of Max 29_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.56 years for cluster 8
# Return Period of Max 56_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.58 years for cluster 10
# Return Period of Max 36_XYLIA Wind Gust: 1.50 years for cluster 2
# Processing event: 8_C3S_STORM_TRACKS_ERA5
# Return Period of Max 96_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.65 years for cluster 13
# Return Period of Max 2_DARIA Wind Gust: 2.01 years for cluster 7
# Return Period of Max 29_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.53 years for cluster 9
# Return Period of Max 73_XAVER Wind Gust: 3.80 years for cluster 1
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.61 years for cluster 5
# Return Period of Max 56_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.75 years for cluster 11
# Return Period of Max 36_XYLIA Wind Gust: 28.69 years for cluster 3
# Return Period of Max 96_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.51 years for cluster 14
# Return Period of Max 2_DARIA Wind Gust: 0.88 years for cluster 8
# Return Period of Max 56_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.65 years for cluster 12
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 5.84 years for cluster 0
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 9.81 years for cluster 6
# Return Period of Max 73_XAVER Wind Gust: 5.34 years for cluster 2
# Return Period of Max 29_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.87 years for cluster 10
# Return Period of Max 36_XYLIA Wind Gust: 7.12 years for cluster 4
# Processing event: 83_C3S_STORM_TRACKS_ERA5
# Return Period of Max 2_DARIA Wind Gust: 0.78 years for cluster 9
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.40 years for cluster 1
# Return Period of Max 29_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.73 years for cluster 11
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.56 years for cluster 7
# Return Period of Max 56_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.67 years for cluster 13
# Return Period of Max 36_XYLIA Wind Gust: 0.79 years for cluster 5
# Return Period of Max 73_XAVER Wind Gust: 104.86 years for cluster 3
# Return Period of Max 56_C3S_STORM_TRACKS_ERA5 Wind Gust: 6.62 years for cluster 14
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.51 years for cluster 8
# Return Period of Max 2_DARIA Wind Gust: 1.05 years for cluster 10
# Return Period of Max 29_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.85 years for cluster 12
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.99 years for cluster 2
# Return Period of Max 73_XAVER Wind Gust: 7.14 years for cluster 4
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 5.82 years for cluster 0
# Return Period of Max 36_XYLIA Wind Gust: 6.12 years for cluster 6
# Processing event: 43_C3S_STORM_TRACKS_ERA5
# Return Period of Max 2_DARIA Wind Gust: 40.13 years for cluster 11
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.62 years for cluster 9
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 8.82 years for cluster 3
# Return Period of Max 29_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.19 years for cluster 13
# Return Period of Max 36_XYLIA Wind Gust: 2.56 years for cluster 7
# Return Period of Max 73_XAVER Wind Gust: 0.57 years for cluster 5
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.76 years for cluster 1
# Return Period of Max 2_DARIA Wind Gust: 20.30 years for cluster 12
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.81 years for cluster 10
# Return Period of Max 36_XYLIA Wind Gust: 0.69 years for cluster 8
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.86 years for cluster 4
# Return Period of Max 29_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.83 years for cluster 14
# Return Period of Max 73_XAVER Wind Gust: 449.33 years for cluster 6
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.23 years for cluster 2
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.43 years for cluster 0
# Return Period of Max 2_DARIA Wind Gust: 0.64 years for cluster 13
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 7.40 years for cluster 11
# Return Period of Max 36_XYLIA Wind Gust: 0.86 years for cluster 9
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.61 years for cluster 5
# Return Period of Max 73_XAVER Wind Gust: 0.93 years for cluster 7
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 28.36 years for cluster 3
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.57 years for cluster 1
# Return Period of Max 2_DARIA Wind Gust: 4.22 years for cluster 14
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.41 years for cluster 12
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 550.17 years for cluster 6
# Return Period of Max 36_XYLIA Wind Gust: 1.66 years for cluster 10
# Return Period of Max 73_XAVER Wind Gust: 0.88 years for cluster 8
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.11 years for cluster 4
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.69 years for cluster 2
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.68 years for cluster 13
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.16 years for cluster 7
# Return Period of Max 36_XYLIA Wind Gust: 0.98 years for cluster 11
# Return Period of Max 73_XAVER Wind Gust: 0.70 years for cluster 9
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.59 years for cluster 5
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.38 years for cluster 3
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.79 years for cluster 14
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.54 years for cluster 8
# Return Period of Max 36_XYLIA Wind Gust: 1.13 years for cluster 12
# Return Period of Max 73_XAVER Wind Gust: 3.27 years for cluster 10
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 33.54 years for cluster 6
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.11 years for cluster 4
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.59 years for cluster 9
# Return Period of Max 36_XYLIA Wind Gust: 1.12 years for cluster 13
# Return Period of Max 73_XAVER Wind Gust: 13.62 years for cluster 11
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.22 years for cluster 7
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.35 years for cluster 5
# Return Period of Max 36_XYLIA Wind Gust: 0.58 years for cluster 14
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.27 years for cluster 10
# Return Period of Max 73_XAVER Wind Gust: 430.50 years for cluster 12
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.74 years for cluster 8
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 15.42 years for cluster 6
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.88 years for cluster 11
# Return Period of Max 73_XAVER Wind Gust: 0.60 years for cluster 13
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.77 years for cluster 9
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.38 years for cluster 7
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.30 years for cluster 12
# Return Period of Max 73_XAVER Wind Gust: 0.58 years for cluster 14
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.84 years for cluster 10
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.59 years for cluster 8
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.71 years for cluster 13
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.63 years for cluster 11
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.54 years for cluster 9
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.81 years for cluster 14
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.86 years for cluster 12
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.86 years for cluster 10
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.54 years for cluster 13
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.28 years for cluster 11
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.32 years for cluster 14
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.98 years for cluster 12
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.92 years for cluster 13
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.63 years for cluster 14

# %%
# Reset index and split 'Unnamed: 0' into 'storm_number' and 'storm_name'
log_cdf_max_all = log_cdf_max_combined.reset_index()
log_cdf_max_all[['storm_number', 'storm_name']] = log_cdf_max_all['index'].str.split('_', n=1, expand=True)

# Drop unnecessary columns
log_cdf_max_all = log_cdf_max_all.drop(columns=['index'])

# Reorder columns to place 'storm_number' and 'storm_name' at the beginning
cols = ['storm_number', 'storm_name'] + [col for col in log_cdf_max_all.columns if col not in ['storm_number', 'storm_name']]
log_cdf_max_all = log_cdf_max_all[cols]

# Save the combined dataframe to multiple locations
log_cdf_max_all.to_csv(f'data/climatology_dm_winter_per_cluster{without_storms}/GEV_CDF_max/log_cdf_max_combined.csv', index=False)
log_cdf_max_all.to_csv(f'pre_processing/nestedMLR/log_cdf_max_combined{without_storms}.csv', index=False)

# Change type of 'storm_number' to integer
log_cdf_max_all['storm_number'] = log_cdf_max_all['storm_number'].astype(int)

# Load storm splits for training, validation, and testing
storm_training_test_valid = pd.read_csv(
    'pre_processing/time_series_i10fg_before_eu/storm_training_test_valid.csv'
)

# Filter and save data for training, validation, and testing
for split, split_name in zip(
    ['training', 'validation', 'test'],
    ['log_cdf_max_training', 'log_cdf_max_validation', 'log_cdf_max_test']
):
    split_df = log_cdf_max_all[log_cdf_max_all['storm_number'].isin(storm_training_test_valid[split])]
    split_df = split_df.drop(columns=['storm_name'])
    
    # Save the split data to multiple locations
    split_df.to_csv(f'data/climatology_dm_winter_per_cluster{without_storms}/GEV_CDF_max/{split_name}.csv', index=False)
    split_df.to_csv(f'pre_processing/nestedMLR/{split_name}{without_storms}.csv', index=False)
