# %%
import os
import sys
import glob
import xarray as xr
import numpy as np
from scipy.stats import genextreme, weibull_min
from joblib import Parallel, delayed
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.distributions.empirical_distribution import ECDF

operating_system = 'mac'

if operating_system == 'win':
    os.chdir('C:/Users/fabau/OneDrive/Documents/GitHub/master-project-cleaned/')
elif operating_system == 'curnagl':
    os.chdir('/work/FAC/FGSE/IDYST/tbeucler/default/fabien/repos/cleaner_version/')
else:
    os.chdir('/Users/fabienaugsburger/Documents/GitHub/master-project-cleaned/')

# Add the path to the custom library
custom_library_path = os.path.abspath('util/processing/')
sys.path.append(custom_library_path)

import time_series

custom_library_path_2 = os.path.abspath('util/gev')
sys.path.append(custom_library_path_2)

import data_processing
from data_processing import depickle, save_to_pickle

# %%
# TAKES 17 MINUTES TO RUN
without_storms = '_no_storms'
from_scratch = False

def initialize_datasets_winter(months, days):
    datasets_winter = []
    for month in months:
        for day in days:
            try:
                dataset = depickle(f'data/climatology/daily_winter_season{without_storms}/climatology_europe_winter_{month}_{day}.pkl')
                datasets_winter.append(dataset)
            except FileNotFoundError:
                print(f'No data for month {month} and day {day}')
    return datasets_winter

def process_storm_file(event, cluster_data_original, datasets_winter, tif_15):
    print(f"Processing event: {event}")
    
    # Storm data
    storm = data_processing.process_daily_climatology(
        f'data/time_series_rasters_storms_15h/{event}.tif', 
        cluster_data_original, 
        event
        )
    
    clusters = range(0, 15)
    log_cdf_max = pd.DataFrame()
    max_event = pd.DataFrame()
    
    for cluster_n in clusters:
        if from_scratch == True:
            dataset_wind_speed = []
            for dataset in datasets_winter:
                for ds in dataset:
                    ds_cluster = ds.where(tif_15['band_data'] == cluster_n)
                    daily_max = ds_cluster['i10fg'].max().values
                    dataset_wind_speed.append(daily_max)
        else:
            dataset_wind_speed = pd.read_csv(f'data/climatology_dm_winter_per_cluster{without_storms}/wind_data_cluster_{cluster_n}.csv')['0'].tolist()
                    
            technic = genextreme
            # Fit the GEV distribution
            shape, loc, scale = technic.fit(dataset_wind_speed)
            storm_subset = storm[storm['cluster_n'] == cluster_n]['wind_speed_None']
            max_storm = storm_subset.max()
            # Compute return period for max_storm
            cdf_max_storm = technic.cdf(max_storm, shape, loc=loc, scale=scale)
            return_period = round((1 / (1 - cdf_max_storm)) / 2, 2)
            log_cdf_max_storm = -np.log(1 - cdf_max_storm)
            log_cdf_max.at[event, f'cluster_{cluster_n}'] = log_cdf_max_storm
            max_event.at[event, f'cluster_{cluster_n}'] = max_storm
            print(f"Return Period of Max {event} Wind Gust: {return_period:.2f} years for cluster {cluster_n} with wind speed of {max_storm:.2f} m/s")

            x_vals = dataset_wind_speed #np.linspace(min(dataset_wind_speed), max(dataset_wind_speed), 1000)
            cdf_vals = technic.cdf(x_vals, shape, loc=loc, scale=scale)

            # Transform CDF to -log10(1-CDF)
            cdf_vals_transformed = -np.log10(1 - cdf_vals)

            # save both in CDF and transformed CDF folders
            pd.DataFrame(cdf_vals).to_csv(f'data/climatology_dm_winter_per_cluster{without_storms}/GEV_CDF/GEV_CDF_cluster_{cluster_n}.csv')
            pd.DataFrame(cdf_vals_transformed).to_csv(f'data/climatology_dm_winter_per_cluster{without_storms}/GEV_CDF_transformed/GEV_CDF_cluster_{cluster_n}.csv')

        # Optional: Plot the transformed CDF
        # plt.plot(x_vals, cdf_vals_transformed, label="GEV Transformed CDF (-log10(1-CDF)")

    return log_cdf_max, max_event

def main_joblib_parallel_processing(path, cluster_csv, months, days, tif_15, n_jobs=-1):
    # Collect all storm files
    files = glob.glob(os.path.join(path, '*.tif'))
    name_tif = [os.path.basename(file) for file in files]
    # Remove 'max_all_storms.tif'
    if 'max_all_storms.tif' in name_tif:
        name_tif.remove('max_all_storms.tif')

    # Load cluster data
    cluster_data_original = pd.read_csv(cluster_csv)

    if from_scratch == True:
        # Initialize datasets_winter
        datasets_winter = initialize_datasets_winter(months, days)
    else:
        datasets_winter = None

    # Run tasks in parallel using joblib
    results = Parallel(n_jobs=n_jobs)(
        delayed(process_storm_file)(file.split('.')[0], cluster_data_original, datasets_winter, tif_15) 
        for file in name_tif
    )
    # Separate log_cdf_max and max_event results
    log_cdf_max_list, max_event_list = zip(*results)
    
    # Combine results across all events
    log_cdf_max_combined = pd.concat(log_cdf_max_list, axis=0)
    max_event_combined = pd.concat(max_event_list, axis=0)

    return log_cdf_max_combined, max_event_combined

# Prepare data for processing
tif_15 = xr.open_dataset('pre_processing/cluster/number_of_clusters/cleaned_cluster_15_v2.tif', engine='rasterio')
tif_15 = tif_15.rename({'x': 'longitude', 'y': 'latitude'})

path = '/Users/fabienaugsburger/Documents/GitHub/master-project-cleaned/data/time_series_rasters_storms_15h/'
cluster_csv = 'pre_processing/cluster/number_of_clusters/cleaned_cluster_15_v2.csv'
months = [10, 11, 12, 1, 2, 3]  # Winter months
days = range(1, 32)  # Days from 01 to 31

# Process all storms in parallel
log_cdf_max_combined, max_event_combined = main_joblib_parallel_processing(path, cluster_csv, months, days, tif_15, n_jobs=-1)
# Out:
# Processing event: 9_C3S_STORM_TRACKS_ERA5
# Processing event: 35_C3S_STORM_TRACKS_ERA5
# Processing event: 82_C3S_STORM_TRACKS_ERA5
# Processing event: 1_C3S_STORM_TRACKS_ERA5
# Processing event: 13_C3S_STORM_TRACKS_ERA5
# Processing event: 95_AIDEN
# Processing event: 7_HERTA
# Processing event: 28_C3S_STORM_TRACKS_ERA5
# Processing event: 92_CIARA2
# Processing event: 79_C3S_STORM_TRACKS_ERA5
# Return Period of Max 82_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.84 years for cluster 0 with wind speed of 24.37 m/s
# Return Period of Max 82_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.13 years for cluster 1 with wind speed of 20.72 m/s
# Return Period of Max 28_C3S_STORM_TRACKS_ERA5 Wind Gust: 47.54 years for cluster 0 with wind speed of 31.54 m/s
# Return Period of Max 82_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.15 years for cluster 2 with wind speed of 22.54 m/s
# Return Period of Max 1_C3S_STORM_TRACKS_ERA5 Wind Gust: 6.63 years for cluster 0 with wind speed of 25.46 m/s
# Return Period of Max 28_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.88 years for cluster 1 with wind speed of 23.55 m/s
# Return Period of Max 95_AIDEN  Wind Gust: 0.55 years for cluster 0 with wind speed of 12.53 m/s
# Return Period of Max 1_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.94 years for cluster 1 with wind speed of 16.16 m/s
# Return Period of Max 82_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.82 years for cluster 3 with wind speed of 24.79 m/s
# Return Period of Max 35_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.65 years for cluster 0 with wind speed of 20.15 m/s
# Return Period of Max 28_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.60 years for cluster 2 with wind speed of 21.05 m/s
# Return Period of Max 95_AIDEN  Wind Gust: 1.10 years for cluster 1 with wind speed of 17.16 m/s
# Return Period of Max 9_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.24 years for cluster 0 with wind speed of 21.45 m/s
# Return Period of Max 1_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.24 years for cluster 2 with wind speed of 22.72 m/s
# Return Period of Max 82_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.22 years for cluster 4 with wind speed of 20.14 m/s
# Return Period of Max 79_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.76 years for cluster 0 with wind speed of 20.43 m/s
# Return Period of Max 35_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.16 years for cluster 1 with wind speed of 17.47 m/s
# Return Period of Max 28_C3S_STORM_TRACKS_ERA5 Wind Gust: 21.01 years for cluster 3 with wind speed of 31.14 m/s
# Return Period of Max 95_AIDEN  Wind Gust: 0.73 years for cluster 2 with wind speed of 16.14 m/s
# Return Period of Max 9_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.93 years for cluster 1 with wind speed of 20.21 m/s
# Return Period of Max 7_HERTA Wind Gust: 1.64 years for cluster 0 with wind speed of 20.11 m/s
# Return Period of Max 1_C3S_STORM_TRACKS_ERA5 Wind Gust: 11.25 years for cluster 3 with wind speed of 29.40 m/s
# Return Period of Max 82_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.87 years for cluster 5 with wind speed of 26.29 m/s
# Return Period of Max 79_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.87 years for cluster 1 with wind speed of 20.07 m/s
# Return Period of Max 35_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.28 years for cluster 2 with wind speed of 22.81 m/s
# Return Period of Max 13_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.74 years for cluster 0 with wind speed of 15.74 m/s
# Return Period of Max 95_AIDEN  Wind Gust: 5.74 years for cluster 3 with wind speed of 27.32 m/s
# Return Period of Max 7_HERTA Wind Gust: 4.37 years for cluster 1 with wind speed of 24.07 m/s
# Return Period of Max 28_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.49 years for cluster 4 with wind speed of 20.54 m/s
# Return Period of Max 9_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.81 years for cluster 2 with wind speed of 16.97 m/s
# Return Period of Max 79_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.63 years for cluster 2 with wind speed of 14.67 m/s
# Return Period of Max 13_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.56 years for cluster 1 with wind speed of 11.19 m/s
# Return Period of Max 1_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.75 years for cluster 4 with wind speed of 15.26 m/s
# Return Period of Max 92_CIARA2 Wind Gust: 308.79 years for cluster 0 with wind speed of 36.43 m/s
# Return Period of Max 35_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.06 years for cluster 3 with wind speed of 26.14 m/s
# Return Period of Max 7_HERTA Wind Gust: 1.16 years for cluster 2 with wind speed of 19.31 m/s
# Return Period of Max 95_AIDEN  Wind Gust: 0.95 years for cluster 4 with wind speed of 16.60 m/s
# Return Period of Max 82_C3S_STORM_TRACKS_ERA5 Wind Gust: 70.63 years for cluster 6 with wind speed of 39.38 m/s
# Return Period of Max 28_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.53 years for cluster 5 with wind speed of 12.61 m/s
# Return Period of Max 9_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.49 years for cluster 3 with wind speed of 25.60 m/s
# Return Period of Max 79_C3S_STORM_TRACKS_ERA5 Wind Gust: 39.65 years for cluster 3 with wind speed of 32.74 m/s
# Return Period of Max 1_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.68 years for cluster 5 with wind speed of 16.46 m/s
# Return Period of Max 92_CIARA2 Wind Gust: 24.76 years for cluster 1 with wind speed of 31.36 m/s
# Return Period of Max 13_C3S_STORM_TRACKS_ERA5 Wind Gust: 5.26 years for cluster 2 with wind speed of 26.58 m/s
# Return Period of Max 95_AIDEN  Wind Gust: 0.57 years for cluster 5 with wind speed of 14.28 m/s
# Return Period of Max 35_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.15 years for cluster 4 with wind speed of 17.56 m/s
# Return Period of Max 82_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.53 years for cluster 7 with wind speed of 20.74 m/s
# Return Period of Max 7_HERTA Wind Gust: 80.18 years for cluster 3 with wind speed of 34.36 m/s
# Return Period of Max 28_C3S_STORM_TRACKS_ERA5 Wind Gust: 348.67 years for cluster 6 with wind speed of 43.28 m/s
# Return Period of Max 9_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.02 years for cluster 4 with wind speed of 16.98 m/s
# Return Period of Max 79_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.77 years for cluster 4 with wind speed of 15.41 m/s
# Return Period of Max 13_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.54 years for cluster 3 with wind speed of 14.05 m/s
# Return Period of Max 92_CIARA2 Wind Gust: 2.35 years for cluster 2 with wind speed of 22.96 m/s
# Return Period of Max 1_C3S_STORM_TRACKS_ERA5 Wind Gust: 30.85 years for cluster 6 with wind speed of 37.02 m/s
# Return Period of Max 35_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.66 years for cluster 5 with wind speed of 16.06 m/s
# Return Period of Max 95_AIDEN  Wind Gust: 27.66 years for cluster 6 with wind speed of 36.69 m/s
# Return Period of Max 7_HERTA Wind Gust: 0.64 years for cluster 4 with wind speed of 14.04 m/s
# Return Period of Max 9_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.90 years for cluster 5 with wind speed of 18.65 m/s
# Return Period of Max 82_C3S_STORM_TRACKS_ERA5 Wind Gust: 10.79 years for cluster 8 with wind speed of 27.20 m/s
# Return Period of Max 28_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.67 years for cluster 7 with wind speed of 12.25 m/s
# Return Period of Max 79_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.98 years for cluster 5 with wind speed of 24.48 m/s
# Return Period of Max 1_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.57 years for cluster 7 with wind speed of 10.24 m/s
# Return Period of Max 92_CIARA2 Wind Gust: 180.71 years for cluster 3 with wind speed of 36.03 m/s
# Return Period of Max 95_AIDEN  Wind Gust: 0.63 years for cluster 7 with wind speed of 11.60 m/s
# Return Period of Max 13_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.80 years for cluster 4 with wind speed of 15.64 m/s
# Return Period of Max 35_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.53 years for cluster 6 with wind speed of 30.38 m/s
# Return Period of Max 7_HERTA Wind Gust: 0.70 years for cluster 5 with wind speed of 16.68 m/s
# Return Period of Max 9_C3S_STORM_TRACKS_ERA5 Wind Gust: 154.36 years for cluster 6 with wind speed of 41.39 m/s
# Return Period of Max 82_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.87 years for cluster 9 with wind speed of 17.15 m/s
# Return Period of Max 13_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.67 years for cluster 5 with wind speed of 16.22 m/s
# Return Period of Max 28_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.54 years for cluster 8 with wind speed of 13.08 m/s
# Return Period of Max 79_C3S_STORM_TRACKS_ERA5 Wind Gust: 328.90 years for cluster 6 with wind speed of 43.15 m/s
# Return Period of Max 95_AIDEN  Wind Gust: 0.83 years for cluster 8 with wind speed of 17.53 m/s
# Return Period of Max 1_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.54 years for cluster 8 with wind speed of 13.24 m/s
# Return Period of Max 92_CIARA2 Wind Gust: 20.81 years for cluster 4 with wind speed of 26.68 m/s
# Return Period of Max 35_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.69 years for cluster 7 with wind speed of 12.56 m/s
# Return Period of Max 7_HERTA Wind Gust: 5.89 years for cluster 6 with wind speed of 31.41 m/s
# Return Period of Max 9_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.14 years for cluster 7 with wind speed of 23.27 m/s
# Return Period of Max 82_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.54 years for cluster 10 with wind speed of 22.38 m/s
# Return Period of Max 92_CIARA2 Wind Gust: 0.65 years for cluster 5 with wind speed of 15.94 m/s
# Return Period of Max 95_AIDEN  Wind Gust: 0.50 years for cluster 9 with wind speed of 8.94 m/s
# Return Period of Max 79_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.42 years for cluster 7 with wind speed of 17.55 m/s
# Return Period of Max 28_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.71 years for cluster 9 with wind speed of 15.60 m/s
# Return Period of Max 13_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.93 years for cluster 6 with wind speed of 26.59 m/s
# Return Period of Max 1_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.50 years for cluster 9 with wind speed of 8.68 m/s
# Return Period of Max 35_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.71 years for cluster 8 with wind speed of 16.45 m/s
# Return Period of Max 7_HERTA Wind Gust: 1.33 years for cluster 7 with wind speed of 17.19 m/s
# Return Period of Max 95_AIDEN  Wind Gust: 0.63 years for cluster 10 with wind speed of 15.06 m/s
# Return Period of Max 1_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.10 years for cluster 10 with wind speed of 23.15 m/s
# Return Period of Max 79_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.28 years for cluster 8 with wind speed of 19.89 m/s
# Return Period of Max 9_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.59 years for cluster 8 with wind speed of 14.68 m/s
# Return Period of Max 92_CIARA2 Wind Gust: 39.84 years for cluster 6 with wind speed of 37.77 m/s
# Return Period of Max 28_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.79 years for cluster 10 with wind speed of 23.91 m/s
# Return Period of Max 13_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.55 years for cluster 7 with wind speed of 9.81 m/s
# Return Period of Max 82_C3S_STORM_TRACKS_ERA5 Wind Gust: 9.60 years for cluster 11 with wind speed of 29.27 m/s
# Return Period of Max 35_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.55 years for cluster 9 with wind speed of 12.53 m/s
# Return Period of Max 7_HERTA Wind Gust: 1.15 years for cluster 8 with wind speed of 19.37 m/s
# Return Period of Max 82_C3S_STORM_TRACKS_ERA5 Wind Gust: 24.56 years for cluster 12 with wind speed of 34.58 m/s
# Return Period of Max 79_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.66 years for cluster 9 with wind speed of 14.95 m/s
# Return Period of Max 92_CIARA2 Wind Gust: 1.20 years for cluster 7 with wind speed of 16.53 m/s
# Return Period of Max 13_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.59 years for cluster 8 with wind speed of 14.67 m/s
# Return Period of Max 95_AIDEN  Wind Gust: 1.25 years for cluster 11 with wind speed of 19.63 m/s
# Return Period of Max 9_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.90 years for cluster 9 with wind speed of 17.36 m/s
# Return Period of Max 1_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.05 years for cluster 11 with wind speed of 22.49 m/s
# Return Period of Max 28_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.74 years for cluster 11 with wind speed of 21.60 m/s
# Return Period of Max 35_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.01 years for cluster 10 with wind speed of 21.44 m/s
# Return Period of Max 7_HERTA Wind Gust: 0.83 years for cluster 9 with wind speed of 16.83 m/s
# Return Period of Max 82_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.17 years for cluster 13 with wind speed of 20.11 m/s
# Return Period of Max 79_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.55 years for cluster 10 with wind speed of 13.29 m/s
# Return Period of Max 95_AIDEN  Wind Gust: 1.05 years for cluster 12 with wind speed of 21.39 m/s
# Return Period of Max 13_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.63 years for cluster 9 with wind speed of 14.44 m/s
# Return Period of Max 28_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.41 years for cluster 12 with wind speed of 25.85 m/s
# Return Period of Max 9_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.19 years for cluster 10 with wind speed of 19.08 m/s
# Return Period of Max 92_CIARA2 Wind Gust: 0.93 years for cluster 8 with wind speed of 18.26 m/s
# Return Period of Max 1_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.95 years for cluster 12 with wind speed of 24.84 m/s
# Return Period of Max 82_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.74 years for cluster 14 with wind speed of 15.13 m/s
# Return Period of Max 35_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.55 years for cluster 11 with wind speed of 26.26 m/s
# Return Period of Max 95_AIDEN  Wind Gust: 0.51 years for cluster 13 with wind speed of 10.94 m/s
# Processing event: 20_C3S_STORM_TRACKS_ERA5
# Return Period of Max 7_HERTA Wind Gust: 0.98 years for cluster 10 with wind speed of 18.10 m/s
# Return Period of Max 13_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.53 years for cluster 10 with wind speed of 22.36 m/s
# Return Period of Max 1_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.64 years for cluster 13 with wind speed of 15.56 m/s
# Return Period of Max 28_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.64 years for cluster 13 with wind speed of 15.51 m/s
# Return Period of Max 79_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.43 years for cluster 11 with wind speed of 20.46 m/s
# Return Period of Max 92_CIARA2 Wind Gust: 0.62 years for cluster 9 with wind speed of 14.26 m/s
# Return Period of Max 9_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.23 years for cluster 11 with wind speed of 22.92 m/s
# Return Period of Max 35_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.23 years for cluster 12 with wind speed of 28.29 m/s
# Return Period of Max 95_AIDEN  Wind Gust: 1.39 years for cluster 14 with wind speed of 19.48 m/s
# Processing event: 57_C3S_STORM_TRACKS_ERA5
# Return Period of Max 1_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.07 years for cluster 14 with wind speed of 17.92 m/s
# Return Period of Max 28_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.66 years for cluster 14 with wind speed of 14.00 m/s
# Return Period of Max 7_HERTA Wind Gust: 4.02 years for cluster 11 with wind speed of 25.72 m/s
# Processing event: 50_C3S_STORM_TRACKS_ERA5
# Return Period of Max 9_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.92 years for cluster 12 with wind speed of 24.76 m/s
# Return Period of Max 79_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.89 years for cluster 12 with wind speed of 20.31 m/s
# Processing event: 90_C3S_STORM_TRACKS_ERA5
# Return Period of Max 92_CIARA2 Wind Gust: 22.88 years for cluster 10 with wind speed of 30.06 m/s
# Return Period of Max 13_C3S_STORM_TRACKS_ERA5 Wind Gust: 10.42 years for cluster 11 with wind speed of 29.58 m/s
# Return Period of Max 35_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.57 years for cluster 13 with wind speed of 14.06 m/s
# Return Period of Max 7_HERTA Wind Gust: 1.88 years for cluster 12 with wind speed of 24.67 m/s
# Return Period of Max 9_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.48 years for cluster 13 with wind speed of 26.03 m/s
# Return Period of Max 79_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.35 years for cluster 13 with wind speed of 20.85 m/s
# Return Period of Max 35_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.96 years for cluster 14 with wind speed of 21.29 m/s
# Return Period of Max 13_C3S_STORM_TRACKS_ERA5 Wind Gust: 49.26 years for cluster 12 with wind speed of 36.69 m/s
# Processing event: 27_C3S_STORM_TRACKS_ERA5
# Return Period of Max 92_CIARA2 Wind Gust: 2.38 years for cluster 11 with wind speed of 23.26 m/s
# Return Period of Max 7_HERTA Wind Gust: 2.15 years for cluster 13 with wind speed of 23.09 m/s
# Return Period of Max 9_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.92 years for cluster 14 with wind speed of 16.92 m/s
# Return Period of Max 79_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.03 years for cluster 14 with wind speed of 21.46 m/s
# Processing event: 58_C3S_STORM_TRACKS_ERA5
# Processing event: 76_C3S_STORM_TRACKS_ERA5
# Return Period of Max 13_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.59 years for cluster 13 with wind speed of 14.64 m/s
# Return Period of Max 7_HERTA Wind Gust: 64.21 years for cluster 14 with wind speed of 33.80 m/s
# Return Period of Max 92_CIARA2 Wind Gust: 2.46 years for cluster 12 with wind speed of 25.95 m/s
# Return Period of Max 13_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.63 years for cluster 14 with wind speed of 13.52 m/s
# Processing event: 71_CHRISTIAN
# Processing event: 14_C3S_STORM_TRACKS_ERA5
# Return Period of Max 92_CIARA2 Wind Gust: 1.39 years for cluster 13 with wind speed of 21.04 m/s
# Return Period of Max 92_CIARA2 Wind Gust: 1.75 years for cluster 14 with wind speed of 20.71 m/s
# Processing event: 63_C3S_STORM_TRACKS_ERA5
# Return Period of Max 57_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.94 years for cluster 0 with wind speed of 17.29 m/s
# Return Period of Max 50_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.09 years for cluster 0 with wind speed of 18.13 m/s
# Return Period of Max 57_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.65 years for cluster 1 with wind speed of 13.20 m/s
# Return Period of Max 90_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.78 years for cluster 0 with wind speed of 16.13 m/s
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 6.60 years for cluster 0 with wind speed of 25.44 m/s
# Return Period of Max 50_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.57 years for cluster 1 with wind speed of 11.50 m/s
# Return Period of Max 27_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.13 years for cluster 0 with wind speed of 18.34 m/s
# Return Period of Max 90_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.54 years for cluster 1 with wind speed of 10.39 m/s
# Return Period of Max 57_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.52 years for cluster 2 with wind speed of 11.61 m/s
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.31 years for cluster 1 with wind speed of 21.11 m/s
# Return Period of Max 71_CHRISTIAN Wind Gust: 10.08 years for cluster 0 with wind speed of 26.85 m/s
# Return Period of Max 50_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.38 years for cluster 2 with wind speed of 20.27 m/s
# Return Period of Max 27_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.19 years for cluster 1 with wind speed of 17.63 m/s
# Return Period of Max 58_C3S_STORM_TRACKS_ERA5 Wind Gust: 22.77 years for cluster 0 with wind speed of 29.40 m/s
# Return Period of Max 90_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.99 years for cluster 2 with wind speed of 25.38 m/s
# Return Period of Max 71_CHRISTIAN Wind Gust: 8.72 years for cluster 1 with wind speed of 27.07 m/s
# Return Period of Max 57_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.25 years for cluster 3 with wind speed of 25.34 m/s
# Return Period of Max 76_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.82 years for cluster 0 with wind speed of 16.49 m/s
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 19.66 years for cluster 2 with wind speed of 32.01 m/s
# Return Period of Max 27_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.52 years for cluster 2 with wind speed of 11.60 m/s
# Return Period of Max 58_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.02 years for cluster 1 with wind speed of 16.64 m/s
# Return Period of Max 50_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.83 years for cluster 3 with wind speed of 23.01 m/s
# Return Period of Max 90_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.99 years for cluster 3 with wind speed of 23.39 m/s
# Return Period of Max 76_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.17 years for cluster 1 with wind speed of 17.51 m/s
# Return Period of Max 71_CHRISTIAN Wind Gust: 0.72 years for cluster 2 with wind speed of 16.02 m/s
# Return Period of Max 14_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.31 years for cluster 0 with wind speed of 21.56 m/s
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.63 years for cluster 3 with wind speed of 25.74 m/s
# Return Period of Max 57_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.11 years for cluster 4 with wind speed of 17.39 m/s
# Return Period of Max 58_C3S_STORM_TRACKS_ERA5 Wind Gust: 5.17 years for cluster 2 with wind speed of 26.51 m/s
# Return Period of Max 27_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.05 years for cluster 3 with wind speed of 25.09 m/s
# Return Period of Max 76_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.70 years for cluster 2 with wind speed of 15.79 m/s
# Return Period of Max 90_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.94 years for cluster 4 with wind speed of 16.54 m/s
# Return Period of Max 63_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.18 years for cluster 0 with wind speed of 18.54 m/s
# Return Period of Max 57_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.59 years for cluster 5 with wind speed of 14.84 m/s
# Return Period of Max 14_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.82 years for cluster 1 with wind speed of 15.20 m/s
# Return Period of Max 71_CHRISTIAN Wind Gust: 40.27 years for cluster 3 with wind speed of 32.78 m/s
# Return Period of Max 50_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.69 years for cluster 4 with wind speed of 14.71 m/s
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 5.96 years for cluster 4 with wind speed of 23.29 m/s
# Return Period of Max 58_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.39 years for cluster 3 with wind speed of 25.49 m/s
# Return Period of Max 76_C3S_STORM_TRACKS_ERA5 Wind Gust: 22.92 years for cluster 3 with wind speed of 31.37 m/s
# Return Period of Max 63_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.92 years for cluster 1 with wind speed of 16.00 m/s
# Return Period of Max 27_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.31 years for cluster 4 with wind speed of 18.12 m/s
# Return Period of Max 14_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.95 years for cluster 2 with wind speed of 26.33 m/s
# Return Period of Max 57_C3S_STORM_TRACKS_ERA5 Wind Gust: 32.36 years for cluster 6 with wind speed of 37.16 m/s
# Return Period of Max 50_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.59 years for cluster 5 with wind speed of 14.83 m/s
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.10 years for cluster 5 with wind speed of 19.88 m/s
# Return Period of Max 90_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.64 years for cluster 5 with wind speed of 15.74 m/s
# Return Period of Max 71_CHRISTIAN Wind Gust: 1.87 years for cluster 4 with wind speed of 19.52 m/s
# Return Period of Max 76_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.56 years for cluster 4 with wind speed of 12.75 m/s
# Return Period of Max 58_C3S_STORM_TRACKS_ERA5 Wind Gust: 14.90 years for cluster 4 with wind speed of 25.83 m/s
# Return Period of Max 71_CHRISTIAN Wind Gust: 0.55 years for cluster 5 with wind speed of 13.52 m/s
# Return Period of Max 14_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.66 years for cluster 3 with wind speed of 26.62 m/s
# Return Period of Max 27_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.62 years for cluster 5 with wind speed of 15.40 m/s
# Return Period of Max 63_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.31 years for cluster 2 with wind speed of 20.00 m/s
# Return Period of Max 90_C3S_STORM_TRACKS_ERA5 Wind Gust: 32.14 years for cluster 6 with wind speed of 37.14 m/s
# Return Period of Max 50_C3S_STORM_TRACKS_ERA5 Wind Gust: 97.57 years for cluster 6 with wind speed of 40.23 m/s
# Return Period of Max 57_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.61 years for cluster 7 with wind speed of 11.23 m/s
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 7.26 years for cluster 6 with wind speed of 32.20 m/s
# Return Period of Max 76_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.60 years for cluster 5 with wind speed of 14.99 m/s
# Return Period of Max 58_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.32 years for cluster 5 with wind speed of 23.48 m/s
# Return Period of Max 14_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.70 years for cluster 4 with wind speed of 22.58 m/s
# Return Period of Max 71_CHRISTIAN Wind Gust: 1.30 years for cluster 6 with wind speed of 24.47 m/s
# Return Period of Max 50_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.53 years for cluster 7 with wind speed of 9.04 m/s
# Return Period of Max 63_C3S_STORM_TRACKS_ERA5 Wind Gust: 7.40 years for cluster 3 with wind speed of 28.14 m/s
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.55 years for cluster 7 with wind speed of 9.85 m/s
# Return Period of Max 90_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.53 years for cluster 7 with wind speed of 9.14 m/s
# Return Period of Max 57_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.53 years for cluster 8 with wind speed of 12.52 m/s
# Return Period of Max 27_C3S_STORM_TRACKS_ERA5 Wind Gust: 20.77 years for cluster 6 with wind speed of 35.79 m/s
# Return Period of Max 76_C3S_STORM_TRACKS_ERA5 Wind Gust: 263.90 years for cluster 6 with wind speed of 42.66 m/s
# Return Period of Max 58_C3S_STORM_TRACKS_ERA5 Wind Gust: 37.72 years for cluster 6 with wind speed of 37.61 m/s
# Return Period of Max 14_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.66 years for cluster 5 with wind speed of 16.17 m/s
# Return Period of Max 63_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.53 years for cluster 4 with wind speed of 11.81 m/s
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.32 years for cluster 8 with wind speed of 20.02 m/s
# Return Period of Max 27_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.62 years for cluster 7 with wind speed of 11.39 m/s
# Return Period of Max 90_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.72 years for cluster 8 with wind speed of 16.53 m/s
# Return Period of Max 50_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.89 years for cluster 8 with wind speed of 18.00 m/s
# Return Period of Max 57_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.54 years for cluster 9 with wind speed of 12.20 m/s
# Return Period of Max 71_CHRISTIAN Wind Gust: 1.44 years for cluster 7 with wind speed of 17.63 m/s
# Return Period of Max 76_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.15 years for cluster 7 with wind speed of 16.31 m/s
# Return Period of Max 58_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.06 years for cluster 7 with wind speed of 15.79 m/s
# Return Period of Max 63_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.52 years for cluster 5 with wind speed of 11.98 m/s
# Return Period of Max 27_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.54 years for cluster 8 with wind speed of 12.94 m/s
# Return Period of Max 14_C3S_STORM_TRACKS_ERA5 Wind Gust: 7.05 years for cluster 6 with wind speed of 32.09 m/s
# Return Period of Max 50_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.65 years for cluster 9 with wind speed of 14.82 m/s
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.58 years for cluster 9 with wind speed of 13.39 m/s
# Return Period of Max 90_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.91 years for cluster 9 with wind speed of 17.46 m/s
# Return Period of Max 71_CHRISTIAN Wind Gust: 0.71 years for cluster 8 with wind speed of 16.42 m/s
# Return Period of Max 57_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.54 years for cluster 10 with wind speed of 13.28 m/s
# Return Period of Max 76_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.62 years for cluster 8 with wind speed of 15.20 m/s
# Return Period of Max 58_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.62 years for cluster 8 with wind speed of 22.80 m/s
# Return Period of Max 63_C3S_STORM_TRACKS_ERA5 Wind Gust: 191.72 years for cluster 6 with wind speed of 41.91 m/s
# Return Period of Max 14_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.57 years for cluster 7 with wind speed of 10.27 m/s
# Return Period of Max 90_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.71 years for cluster 10 with wind speed of 20.75 m/s
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.69 years for cluster 10 with wind speed of 23.80 m/s
# Return Period of Max 50_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.67 years for cluster 10 with wind speed of 15.64 m/s
# Return Period of Max 27_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.51 years for cluster 9 with wind speed of 10.58 m/s
# Return Period of Max 71_CHRISTIAN Wind Gust: 0.80 years for cluster 9 with wind speed of 16.59 m/s
# Return Period of Max 76_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.66 years for cluster 9 with wind speed of 14.98 m/s
# Return Period of Max 58_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.72 years for cluster 9 with wind speed of 20.75 m/s
# Return Period of Max 57_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.92 years for cluster 11 with wind speed of 17.50 m/s
# Return Period of Max 63_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.68 years for cluster 7 with wind speed of 12.41 m/s
# Return Period of Max 27_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.84 years for cluster 10 with wind speed of 17.24 m/s
# Return Period of Max 71_CHRISTIAN Wind Gust: 1.12 years for cluster 10 with wind speed of 18.79 m/s
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 1478.25 years for cluster 11 with wind speed of 43.06 m/s
# Return Period of Max 14_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.58 years for cluster 8 with wind speed of 14.27 m/s
# Return Period of Max 50_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.53 years for cluster 11 with wind speed of 20.87 m/s
# Return Period of Max 76_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.64 years for cluster 10 with wind speed of 15.16 m/s
# Return Period of Max 90_C3S_STORM_TRACKS_ERA5 Wind Gust: 8.19 years for cluster 11 with wind speed of 28.66 m/s
# Return Period of Max 57_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.70 years for cluster 12 with wind speed of 18.28 m/s
# Return Period of Max 63_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.51 years for cluster 8 with wind speed of 10.89 m/s
# Return Period of Max 58_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.58 years for cluster 10 with wind speed of 23.70 m/s
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 534.72 years for cluster 12 with wind speed of 42.80 m/s
# Return Period of Max 50_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.37 years for cluster 12 with wind speed of 22.99 m/s
# Return Period of Max 90_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.88 years for cluster 12 with wind speed of 28.86 m/s
# Return Period of Max 14_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.50 years for cluster 9 with wind speed of 7.97 m/s
# Return Period of Max 27_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.57 years for cluster 11 with wind speed of 12.22 m/s
# Return Period of Max 71_CHRISTIAN Wind Gust: 0.96 years for cluster 11 with wind speed of 17.77 m/s
# Return Period of Max 57_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.52 years for cluster 13 with wind speed of 11.39 m/s
# Return Period of Max 76_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.46 years for cluster 11 with wind speed of 23.42 m/s
# Return Period of Max 50_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.51 years for cluster 13 with wind speed of 10.40 m/s
# Return Period of Max 63_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.51 years for cluster 9 with wind speed of 10.16 m/s
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.53 years for cluster 13 with wind speed of 12.20 m/s
# Return Period of Max 27_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.51 years for cluster 12 with wind speed of 12.14 m/s
# Return Period of Max 58_C3S_STORM_TRACKS_ERA5 Wind Gust: 63.81 years for cluster 11 with wind speed of 35.55 m/s
# Return Period of Max 14_C3S_STORM_TRACKS_ERA5 Wind Gust: 5.93 years for cluster 10 with wind speed of 25.53 m/s
# Return Period of Max 57_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.77 years for cluster 14 with wind speed of 15.51 m/s
# Return Period of Max 90_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.58 years for cluster 13 with wind speed of 14.21 m/s
# Return Period of Max 76_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.32 years for cluster 12 with wind speed of 22.80 m/s
# Return Period of Max 71_CHRISTIAN Wind Gust: 0.56 years for cluster 12 with wind speed of 15.46 m/s
# Processing event: 48_GERO
# Return Period of Max 20_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.58 years for cluster 14 with wind speed of 12.29 m/s
# Return Period of Max 50_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.09 years for cluster 14 with wind speed of 18.04 m/s
# Return Period of Max 63_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.62 years for cluster 10 with wind speed of 14.96 m/s
# Processing event: 45_C3S_STORM_TRACKS_ERA5
# Return Period of Max 27_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.58 years for cluster 13 with wind speed of 14.17 m/s
# Processing event: 85_C3S_STORM_TRACKS_ERA5
# Return Period of Max 76_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.01 years for cluster 13 with wind speed of 19.20 m/s
# Return Period of Max 58_C3S_STORM_TRACKS_ERA5 Wind Gust: 69.43 years for cluster 12 with wind speed of 37.68 m/s
# Return Period of Max 90_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.05 years for cluster 14 with wind speed of 17.82 m/s
# Return Period of Max 71_CHRISTIAN Wind Gust: 0.83 years for cluster 13 with wind speed of 17.89 m/s
# Processing event: 6_WIEBKE
# Return Period of Max 14_C3S_STORM_TRACKS_ERA5 Wind Gust: 5.73 years for cluster 11 with wind speed of 27.23 m/s
# Return Period of Max 27_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.88 years for cluster 14 with wind speed of 16.54 m/s
# Return Period of Max 76_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.75 years for cluster 14 with wind speed of 24.21 m/s
# Processing event: 65_XYNTHIA
# Processing event: 19_C3S_STORM_TRACKS_ERA5
# Return Period of Max 71_CHRISTIAN Wind Gust: 5.26 years for cluster 14 with wind speed of 25.59 m/s
# Return Period of Max 58_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.94 years for cluster 13 with wind speed of 18.73 m/s
# Return Period of Max 63_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.73 years for cluster 11 with wind speed of 23.92 m/s
# Processing event: 61_EMMA
# Return Period of Max 14_C3S_STORM_TRACKS_ERA5 Wind Gust: 6.03 years for cluster 12 with wind speed of 29.69 m/s
# Return Period of Max 58_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.77 years for cluster 14 with wind speed of 15.50 m/s
# Processing event: 80_C3S_STORM_TRACKS_ERA5
# Return Period of Max 14_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.50 years for cluster 13 with wind speed of 9.77 m/s
# Return Period of Max 63_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.39 years for cluster 12 with wind speed of 23.07 m/s
# Return Period of Max 14_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.58 years for cluster 14 with wind speed of 20.20 m/s
# Return Period of Max 63_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.59 years for cluster 13 with wind speed of 14.49 m/s
# Processing event: 11_C3S_STORM_TRACKS_ERA5
# Return Period of Max 63_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.13 years for cluster 14 with wind speed of 18.27 m/s
# Processing event: 46_JEANETTE
# Return Period of Max 6_WIEBKE Wind Gust: 41.64 years for cluster 0 with wind speed of 31.16 m/s
# Return Period of Max 85_C3S_STORM_TRACKS_ERA5 Wind Gust: 29.07 years for cluster 0 with wind speed of 30.12 m/s
# Return Period of Max 85_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.97 years for cluster 1 with wind speed of 16.33 m/s
# Return Period of Max 6_WIEBKE Wind Gust: 39.72 years for cluster 1 with wind speed of 33.23 m/s
# Return Period of Max 45_C3S_STORM_TRACKS_ERA5 Wind Gust: 21.71 years for cluster 0 with wind speed of 29.26 m/s
# Return Period of Max 65_XYNTHIA Wind Gust: 0.99 years for cluster 0 with wind speed of 17.62 m/s
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 19.23 years for cluster 0 with wind speed of 28.89 m/s
# Return Period of Max 48_GERO Wind Gust: 1.75 years for cluster 0 with wind speed of 20.39 m/s
# Return Period of Max 85_C3S_STORM_TRACKS_ERA5 Wind Gust: 8.90 years for cluster 2 with wind speed of 28.80 m/s
# Return Period of Max 6_WIEBKE Wind Gust: 1.21 years for cluster 2 with wind speed of 19.52 m/s
# Return Period of Max 45_C3S_STORM_TRACKS_ERA5 Wind Gust: 7.63 years for cluster 1 with wind speed of 26.51 m/s
# Return Period of Max 61_EMMA Wind Gust: 12.63 years for cluster 0 with wind speed of 27.58 m/s
# Return Period of Max 65_XYNTHIA Wind Gust: 10.24 years for cluster 1 with wind speed of 27.75 m/s
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 15.89 years for cluster 1 with wind speed of 29.57 m/s
# Return Period of Max 48_GERO Wind Gust: 0.74 years for cluster 1 with wind speed of 14.36 m/s
# Return Period of Max 80_C3S_STORM_TRACKS_ERA5 Wind Gust: 20.23 years for cluster 0 with wind speed of 29.04 m/s
# Return Period of Max 85_C3S_STORM_TRACKS_ERA5 Wind Gust: 5.67 years for cluster 3 with wind speed of 27.28 m/s
# Return Period of Max 61_EMMA Wind Gust: 5.44 years for cluster 1 with wind speed of 25.05 m/s
# Return Period of Max 6_WIEBKE Wind Gust: 320.45 years for cluster 3 with wind speed of 37.10 m/s
# Return Period of Max 45_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.56 years for cluster 2 with wind speed of 13.03 m/s
# Return Period of Max 48_GERO Wind Gust: 9.89 years for cluster 2 with wind speed of 29.24 m/s
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.10 years for cluster 2 with wind speed of 18.96 m/s
# Return Period of Max 80_C3S_STORM_TRACKS_ERA5 Wind Gust: 49.99 years for cluster 1 with wind speed of 34.12 m/s
# Return Period of Max 65_XYNTHIA Wind Gust: 0.78 years for cluster 2 with wind speed of 16.69 m/s
# Return Period of Max 85_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.86 years for cluster 4 with wind speed of 21.00 m/s
# Return Period of Max 61_EMMA Wind Gust: 0.67 years for cluster 2 with wind speed of 15.44 m/s
# Return Period of Max 11_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.52 years for cluster 0 with wind speed of 11.46 m/s
# Return Period of Max 45_C3S_STORM_TRACKS_ERA5 Wind Gust: 24.41 years for cluster 3 with wind speed of 31.53 m/s
# Return Period of Max 48_GERO Wind Gust: 3.24 years for cluster 3 with wind speed of 25.32 m/s
# Return Period of Max 6_WIEBKE Wind Gust: 26.05 years for cluster 4 with wind speed of 27.24 m/s
# Return Period of Max 80_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.71 years for cluster 2 with wind speed of 21.40 m/s
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 27.93 years for cluster 3 with wind speed of 31.88 m/s
# Return Period of Max 65_XYNTHIA Wind Gust: 57.94 years for cluster 3 with wind speed of 33.63 m/s
# Return Period of Max 85_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.56 years for cluster 5 with wind speed of 13.80 m/s
# Return Period of Max 11_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.60 years for cluster 1 with wind speed of 12.13 m/s
# Return Period of Max 61_EMMA Wind Gust: 27.57 years for cluster 3 with wind speed of 31.85 m/s
# Return Period of Max 6_WIEBKE Wind Gust: 1575.69 years for cluster 5 with wind speed of 39.46 m/s
# Return Period of Max 45_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.70 years for cluster 4 with wind speed of 19.16 m/s
# Return Period of Max 80_C3S_STORM_TRACKS_ERA5 Wind Gust: 11.85 years for cluster 3 with wind speed of 29.56 m/s
# Return Period of Max 48_GERO Wind Gust: 0.87 years for cluster 4 with wind speed of 16.17 m/s
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.25 years for cluster 4 with wind speed of 17.89 m/s
# Return Period of Max 65_XYNTHIA Wind Gust: 1.12 years for cluster 4 with wind speed of 17.42 m/s
# Return Period of Max 46_JEANETTE Wind Gust: 8.85 years for cluster 0 with wind speed of 26.43 m/s
# Return Period of Max 11_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.99 years for cluster 2 with wind speed of 18.36 m/s
# Return Period of Max 61_EMMA Wind Gust: 0.95 years for cluster 4 with wind speed of 16.63 m/s
# Return Period of Max 85_C3S_STORM_TRACKS_ERA5 Wind Gust: 6941.85 years for cluster 6 with wind speed of 48.81 m/s
# Return Period of Max 6_WIEBKE Wind Gust: 12.68 years for cluster 6 with wind speed of 34.18 m/s
# Return Period of Max 45_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.03 years for cluster 5 with wind speed of 19.52 m/s
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.79 years for cluster 5 with wind speed of 17.72 m/s
# Return Period of Max 48_GERO Wind Gust: 0.51 years for cluster 5 with wind speed of 10.20 m/s
# Return Period of Max 80_C3S_STORM_TRACKS_ERA5 Wind Gust: 14.15 years for cluster 4 with wind speed of 25.69 m/s
# Return Period of Max 46_JEANETTE Wind Gust: 8.57 years for cluster 1 with wind speed of 27.00 m/s
# Return Period of Max 65_XYNTHIA Wind Gust: 2.87 years for cluster 5 with wind speed of 24.34 m/s
# Return Period of Max 11_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.15 years for cluster 3 with wind speed of 20.76 m/s
# Return Period of Max 61_EMMA Wind Gust: 0.60 years for cluster 5 with wind speed of 14.95 m/s
# Return Period of Max 85_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.78 years for cluster 7 with wind speed of 13.58 m/s
# Return Period of Max 6_WIEBKE Wind Gust: 5.61 years for cluster 7 with wind speed of 24.81 m/s
# Return Period of Max 45_C3S_STORM_TRACKS_ERA5 Wind Gust: 7.23 years for cluster 6 with wind speed of 32.18 m/s
# Return Period of Max 80_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.82 years for cluster 5 with wind speed of 24.27 m/s
# Return Period of Max 46_JEANETTE Wind Gust: 0.98 years for cluster 2 with wind speed of 18.27 m/s
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 87.51 years for cluster 6 with wind speed of 39.95 m/s
# Return Period of Max 48_GERO Wind Gust: 8148.94 years for cluster 6 with wind speed of 49.05 m/s
# Return Period of Max 65_XYNTHIA Wind Gust: 4.70 years for cluster 6 with wind speed of 30.52 m/s
# Return Period of Max 11_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.54 years for cluster 4 with wind speed of 12.09 m/s
# Return Period of Max 61_EMMA Wind Gust: 19.64 years for cluster 6 with wind speed of 35.62 m/s
# Return Period of Max 46_JEANETTE Wind Gust: 31.56 years for cluster 3 with wind speed of 32.19 m/s
# Return Period of Max 45_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.44 years for cluster 7 with wind speed of 17.62 m/s
# Return Period of Max 85_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.51 years for cluster 8 with wind speed of 11.66 m/s
# Return Period of Max 80_C3S_STORM_TRACKS_ERA5 Wind Gust: 87.28 years for cluster 6 with wind speed of 39.94 m/s
# Return Period of Max 6_WIEBKE Wind Gust: 27.21 years for cluster 8 with wind speed of 29.55 m/s
# Return Period of Max 48_GERO Wind Gust: 0.50 years for cluster 7 with wind speed of 6.63 m/s
# Return Period of Max 11_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.53 years for cluster 5 with wind speed of 12.47 m/s
# Return Period of Max 65_XYNTHIA Wind Gust: 4.56 years for cluster 7 with wind speed of 23.77 m/s
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 5.17 years for cluster 7 with wind speed of 24.40 m/s
# Return Period of Max 61_EMMA Wind Gust: 2.45 years for cluster 7 with wind speed of 20.56 m/s
# Return Period of Max 85_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.57 years for cluster 9 with wind speed of 13.05 m/s
# Return Period of Max 80_C3S_STORM_TRACKS_ERA5 Wind Gust: 38.22 years for cluster 7 with wind speed of 34.44 m/s
# Return Period of Max 46_JEANETTE Wind Gust: 1.70 years for cluster 4 with wind speed of 19.15 m/s
# Return Period of Max 45_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.91 years for cluster 8 with wind speed of 21.61 m/s
# Return Period of Max 6_WIEBKE Wind Gust: 0.82 years for cluster 9 with wind speed of 16.76 m/s
# Return Period of Max 48_GERO Wind Gust: 0.51 years for cluster 8 with wind speed of 11.12 m/s
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.77 years for cluster 8 with wind speed of 16.98 m/s
# Return Period of Max 11_C3S_STORM_TRACKS_ERA5 Wind Gust: 8.24 years for cluster 6 with wind speed of 32.66 m/s
# Return Period of Max 85_C3S_STORM_TRACKS_ERA5 Wind Gust: 10.16 years for cluster 10 with wind speed of 27.39 m/s
# Return Period of Max 65_XYNTHIA Wind Gust: 1.20 years for cluster 8 with wind speed of 19.58 m/s
# Return Period of Max 46_JEANETTE Wind Gust: 0.66 years for cluster 5 with wind speed of 16.12 m/s
# Return Period of Max 61_EMMA Wind Gust: 0.62 years for cluster 8 with wind speed of 15.09 m/s
# Return Period of Max 80_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.26 years for cluster 8 with wind speed of 23.56 m/s
# Return Period of Max 11_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.75 years for cluster 7 with wind speed of 13.29 m/s
# Return Period of Max 45_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.62 years for cluster 9 with wind speed of 14.26 m/s
# Return Period of Max 6_WIEBKE Wind Gust: 1.97 years for cluster 10 with wind speed of 21.35 m/s
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.62 years for cluster 9 with wind speed of 14.32 m/s
# Return Period of Max 48_GERO Wind Gust: 0.50 years for cluster 9 with wind speed of 8.80 m/s
# Return Period of Max 61_EMMA Wind Gust: 0.51 years for cluster 9 with wind speed of 9.50 m/s
# Return Period of Max 65_XYNTHIA Wind Gust: 5509.30 years for cluster 9 with wind speed of 38.81 m/s
# Return Period of Max 46_JEANETTE Wind Gust: 27.19 years for cluster 6 with wind speed of 36.63 m/s
# Return Period of Max 85_C3S_STORM_TRACKS_ERA5 Wind Gust: 10228.42 years for cluster 11 with wind speed of 46.40 m/s
# Return Period of Max 80_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.64 years for cluster 9 with wind speed of 14.66 m/s
# Return Period of Max 45_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.36 years for cluster 10 with wind speed of 19.73 m/s
# Return Period of Max 11_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.51 years for cluster 8 with wind speed of 11.65 m/s
# Return Period of Max 48_GERO Wind Gust: 1.76 years for cluster 10 with wind speed of 20.87 m/s
# Return Period of Max 6_WIEBKE Wind Gust: 0.68 years for cluster 11 with wind speed of 14.68 m/s
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.07 years for cluster 10 with wind speed of 18.58 m/s
# Return Period of Max 65_XYNTHIA Wind Gust: 0.79 years for cluster 10 with wind speed of 16.80 m/s
# Return Period of Max 61_EMMA Wind Gust: 0.81 years for cluster 10 with wind speed of 17.01 m/s
# Return Period of Max 85_C3S_STORM_TRACKS_ERA5 Wind Gust: 27660.28 years for cluster 12 with wind speed of 49.95 m/s
# Return Period of Max 6_WIEBKE Wind Gust: 0.76 years for cluster 12 with wind speed of 19.01 m/s
# Return Period of Max 46_JEANETTE Wind Gust: 1.24 years for cluster 7 with wind speed of 16.77 m/s
# Return Period of Max 11_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.52 years for cluster 9 with wind speed of 10.99 m/s
# Return Period of Max 80_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.61 years for cluster 10 with wind speed of 22.48 m/s
# Return Period of Max 45_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.06 years for cluster 11 with wind speed of 18.51 m/s
# Return Period of Max 48_GERO Wind Gust: 4.88 years for cluster 11 with wind speed of 26.55 m/s
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.91 years for cluster 11 with wind speed of 17.42 m/s
# Return Period of Max 6_WIEBKE Wind Gust: 10.82 years for cluster 13 with wind speed of 29.04 m/s
# Return Period of Max 65_XYNTHIA Wind Gust: 0.52 years for cluster 11 with wind speed of 9.58 m/s
# Return Period of Max 85_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.52 years for cluster 13 with wind speed of 11.32 m/s
# Return Period of Max 61_EMMA Wind Gust: 1.14 years for cluster 11 with wind speed of 19.02 m/s
# Return Period of Max 46_JEANETTE Wind Gust: 0.65 years for cluster 8 with wind speed of 15.70 m/s
# Return Period of Max 48_GERO Wind Gust: 4.80 years for cluster 12 with wind speed of 28.80 m/s
# Return Period of Max 11_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.64 years for cluster 10 with wind speed of 15.23 m/s
# Return Period of Max 45_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.66 years for cluster 12 with wind speed of 17.68 m/s
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.75 years for cluster 12 with wind speed of 18.92 m/s
# Return Period of Max 85_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.61 years for cluster 14 with wind speed of 13.02 m/s
# Return Period of Max 80_C3S_STORM_TRACKS_ERA5 Wind Gust: 9.49 years for cluster 11 with wind speed of 29.23 m/s
# Return Period of Max 6_WIEBKE Wind Gust: 1.00 years for cluster 14 with wind speed of 17.48 m/s
# Return Period of Max 65_XYNTHIA Wind Gust: 0.55 years for cluster 12 with wind speed of 14.82 m/s
# Processing event: 66_C3S_STORM_TRACKS_ERA5
# Return Period of Max 61_EMMA Wind Gust: 1.31 years for cluster 12 with wind speed of 22.75 m/s
# Processing event: 3_C3S_STORM_TRACKS_ERA5
# Return Period of Max 46_JEANETTE Wind Gust: 0.53 years for cluster 9 with wind speed of 11.70 m/s
# Return Period of Max 48_GERO Wind Gust: 0.50 years for cluster 13 with wind speed of 7.61 m/s
# Return Period of Max 45_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.89 years for cluster 13 with wind speed of 18.41 m/s
# Return Period of Max 19_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.30 years for cluster 13 with wind speed of 23.39 m/s
# Return Period of Max 80_C3S_STORM_TRACKS_ERA5 Wind Gust: 5.74 years for cluster 12 with wind speed of 29.50 m/s
# Return Period of Max 65_XYNTHIA Wind Gust: 8.94 years for cluster 13 with wind speed of 28.43 m/s
# Return Period of Max 61_EMMA Wind Gust: 0.79 years for cluster 13 with wind speed of 17.55 m/s
# Return Period of Max 11_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.74 years for cluster 11 with wind speed of 21.59 m/s
# Return Period of Max 46_JEANETTE Wind Gust: 0.97 years for cluster 10 with wind speed of 18.06 m/s
# Return Period of Max 48_GERO Wind Gust: 0.87 years for cluster 14 with wind speed of 16.48 m/s
# ...
# Return Period of Max 56_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.23 years for cluster 7 with wind speed of 22.01 m/s
# Return Period of Max 51_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.43 years for cluster 10 with wind speed of 19.97 m/s
# Return Period of Max 96_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.04 years for cluster 6 with wind speed of 23.10 m/s
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.55 years for cluster 1 with wind speed of 10.89 m/s
# Return Period of Max 2_DARIA Wind Gust: 1208.01 years for cluster 3 with wind speed of 39.28 m/s
# Return Period of Max 78_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.72 years for cluster 7 with wind speed of 22.73 m/s
# Return Period of Max 26_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.59 years for cluster 8 with wind speed of 14.66 m/s
# Return Period of Max 29_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.76 years for cluster 5 with wind speed of 22.28 m/s
# Return Period of Max 56_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.96 years for cluster 8 with wind speed of 18.42 m/s
# Return Period of Max 96_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.60 years for cluster 7 with wind speed of 10.99 m/s
# Return Period of Max 51_C3S_STORM_TRACKS_ERA5 Wind Gust: 12.93 years for cluster 11 with wind speed of 30.37 m/s
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 14.72 years for cluster 2 with wind speed of 30.85 m/s
# Return Period of Max 78_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.73 years for cluster 8 with wind speed of 21.20 m/s
# Return Period of Max 2_DARIA Wind Gust: 3.90 years for cluster 4 with wind speed of 22.01 m/s
# Return Period of Max 29_C3S_STORM_TRACKS_ERA5 Wind Gust: 43.70 years for cluster 6 with wind speed of 38.04 m/s
# Return Period of Max 36_XYLIA Wind Gust: 38.95 years for cluster 0 with wind speed of 30.97 m/s
# Return Period of Max 26_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.52 years for cluster 9 with wind speed of 10.65 m/s
# Return Period of Max 51_C3S_STORM_TRACKS_ERA5 Wind Gust: 12.55 years for cluster 12 with wind speed of 32.35 m/s
# Return Period of Max 96_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.88 years for cluster 8 with wind speed of 17.89 m/s
# Return Period of Max 56_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.89 years for cluster 9 with wind speed of 21.14 m/s
# Return Period of Max 2_DARIA Wind Gust: 0.64 years for cluster 5 with wind speed of 15.84 m/s
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 5.43 years for cluster 3 with wind speed of 27.13 m/s
# Return Period of Max 78_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.44 years for cluster 9 with wind speed of 19.94 m/s
# Return Period of Max 36_XYLIA Wind Gust: 2.93 years for cluster 1 with wind speed of 22.25 m/s
# Return Period of Max 29_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.26 years for cluster 7 with wind speed of 22.06 m/s
# Return Period of Max 26_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.07 years for cluster 10 with wind speed of 18.57 m/s
# Return Period of Max 51_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.51 years for cluster 13 with wind speed of 10.72 m/s
# Return Period of Max 56_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.58 years for cluster 10 with wind speed of 14.19 m/s
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.93 years for cluster 4 with wind speed of 16.50 m/s
# Return Period of Max 96_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.52 years for cluster 9 with wind speed of 10.86 m/s
# Return Period of Max 36_XYLIA Wind Gust: 1.43 years for cluster 2 with wind speed of 20.46 m/s
# Return Period of Max 78_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.71 years for cluster 10 with wind speed of 16.08 m/s
# Return Period of Max 2_DARIA Wind Gust: 327.80 years for cluster 6 with wind speed of 43.14 m/s
# Return Period of Max 29_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.42 years for cluster 8 with wind speed of 20.36 m/s
# Return Period of Max 51_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.57 years for cluster 14 with wind speed of 12.09 m/s
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.62 years for cluster 5 with wind speed of 15.35 m/s
# Return Period of Max 26_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.72 years for cluster 11 with wind speed of 23.91 m/s
# Return Period of Max 56_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.99 years for cluster 11 with wind speed of 18.07 m/s
# Processing event: 8_C3S_STORM_TRACKS_ERA5
# Return Period of Max 36_XYLIA Wind Gust: 30.08 years for cluster 3 with wind speed of 32.07 m/s
# Return Period of Max 96_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.23 years for cluster 10 with wind speed of 24.31 m/s
# Return Period of Max 2_DARIA Wind Gust: 2.05 years for cluster 7 with wind speed of 19.62 m/s
# Return Period of Max 29_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.53 years for cluster 9 with wind speed of 11.57 m/s
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 11.59 years for cluster 6 with wind speed of 33.87 m/s
# Return Period of Max 78_C3S_STORM_TRACKS_ERA5 Wind Gust: 5.49 years for cluster 11 with wind speed of 27.05 m/s
# Return Period of Max 26_C3S_STORM_TRACKS_ERA5 Wind Gust: 7.41 years for cluster 12 with wind speed of 30.47 m/s
# Return Period of Max 36_XYLIA Wind Gust: 7.39 years for cluster 4 with wind speed of 23.92 m/s
# Return Period of Max 56_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.66 years for cluster 12 with wind speed of 17.74 m/s
# Return Period of Max 26_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.54 years for cluster 13 with wind speed of 13.02 m/s
# Return Period of Max 78_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.36 years for cluster 12 with wind speed of 25.76 m/s
# Return Period of Max 96_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.76 years for cluster 11 with wind speed of 21.68 m/s
# Return Period of Max 2_DARIA Wind Gust: 0.84 years for cluster 8 with wind speed of 17.62 m/s
# Return Period of Max 29_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.36 years for cluster 10 with wind speed of 19.72 m/s
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.55 years for cluster 7 with wind speed of 9.92 m/s
# Return Period of Max 36_XYLIA Wind Gust: 0.72 years for cluster 5 with wind speed of 16.94 m/s
# Return Period of Max 56_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.06 years for cluster 13 with wind speed of 22.90 m/s
# Return Period of Max 96_C3S_STORM_TRACKS_ERA5 Wind Gust: 84.29 years for cluster 12 with wind speed of 38.22 m/s
# Return Period of Max 78_C3S_STORM_TRACKS_ERA5 Wind Gust: 5.03 years for cluster 13 with wind speed of 26.46 m/s
# Return Period of Max 26_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.52 years for cluster 14 with wind speed of 9.55 m/s
# Return Period of Max 56_C3S_STORM_TRACKS_ERA5 Wind Gust: 5.10 years for cluster 14 with wind speed of 25.47 m/s
# Processing event: 83_C3S_STORM_TRACKS_ERA5
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.51 years for cluster 8 with wind speed of 10.55 m/s
# Return Period of Max 2_DARIA Wind Gust: 0.78 years for cluster 9 with wind speed of 16.35 m/s
# Return Period of Max 36_XYLIA Wind Gust: 6.93 years for cluster 6 with wind speed of 32.02 m/s
# Return Period of Max 29_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.13 years for cluster 11 with wind speed of 24.58 m/s
# Processing event: 43_C3S_STORM_TRACKS_ERA5
# Return Period of Max 78_C3S_STORM_TRACKS_ERA5 Wind Gust: 5.04 years for cluster 14 with wind speed of 25.42 m/s
# Return Period of Max 96_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.75 years for cluster 13 with wind speed of 17.11 m/s
# Return Period of Max 2_DARIA Wind Gust: 1.04 years for cluster 10 with wind speed of 18.43 m/s
# Return Period of Max 29_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.07 years for cluster 12 with wind speed of 25.13 m/s
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.67 years for cluster 9 with wind speed of 15.12 m/s
# Return Period of Max 96_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.52 years for cluster 14 with wind speed of 9.76 m/s
# Return Period of Max 36_XYLIA Wind Gust: 2.62 years for cluster 7 with wind speed of 20.91 m/s
# Return Period of Max 29_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.70 years for cluster 13 with wind speed of 24.06 m/s
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.80 years for cluster 10 with wind speed of 20.97 m/s
# Return Period of Max 36_XYLIA Wind Gust: 0.67 years for cluster 8 with wind speed of 15.99 m/s
# Return Period of Max 2_DARIA Wind Gust: 53.73 years for cluster 11 with wind speed of 35.04 m/s
# Return Period of Max 29_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.51 years for cluster 14 with wind speed of 19.96 m/s
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.97 years for cluster 11 with wind speed of 24.33 m/s
# Return Period of Max 2_DARIA Wind Gust: 21.23 years for cluster 12 with wind speed of 34.11 m/s
# Return Period of Max 36_XYLIA Wind Gust: 0.85 years for cluster 9 with wind speed of 16.98 m/s
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 5.00 years for cluster 12 with wind speed of 28.96 m/s
# Return Period of Max 2_DARIA Wind Gust: 2.59 years for cluster 13 with wind speed of 23.89 m/s
# Return Period of Max 36_XYLIA Wind Gust: 2.02 years for cluster 10 with wind speed of 21.45 m/s
# Return Period of Max 2_DARIA Wind Gust: 4.79 years for cluster 14 with wind speed of 25.22 m/s
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.79 years for cluster 13 with wind speed of 17.54 m/s
# Return Period of Max 36_XYLIA Wind Gust: 1.08 years for cluster 11 with wind speed of 18.67 m/s
# Return Period of Max 12_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.39 years for cluster 14 with wind speed of 23.79 m/s
# Return Period of Max 36_XYLIA Wind Gust: 1.06 years for cluster 12 with wind speed of 21.50 m/s
# Return Period of Max 36_XYLIA Wind Gust: 1.37 years for cluster 13 with wind speed of 20.94 m/s
# Return Period of Max 36_XYLIA Wind Gust: 0.62 years for cluster 14 with wind speed of 13.27 m/s
# Return Period of Max 73_XAVER Wind Gust: 6722.95 years for cluster 0 with wind speed of 43.05 m/s
# Return Period of Max 73_XAVER Wind Gust: 3.62 years for cluster 1 with wind speed of 23.23 m/s
# Return Period of Max 73_XAVER Wind Gust: 5.13 years for cluster 2 with wind speed of 26.48 m/s
# Return Period of Max 73_XAVER Wind Gust: 113.67 years for cluster 3 with wind speed of 35.10 m/s
# Return Period of Max 73_XAVER Wind Gust: 7.41 years for cluster 4 with wind speed of 23.93 m/s
# Return Period of Max 73_XAVER Wind Gust: 0.66 years for cluster 5 with wind speed of 16.17 m/s
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 5.84 years for cluster 0 with wind speed of 25.02 m/s
# Return Period of Max 73_XAVER Wind Gust: 1043.14 years for cluster 6 with wind speed of 45.55 m/s
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.65 years for cluster 1 with wind speed of 23.27 m/s
# Return Period of Max 73_XAVER Wind Gust: 0.94 years for cluster 7 with wind speed of 14.98 m/s
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.94 years for cluster 2 with wind speed of 18.02 m/s
# Return Period of Max 73_XAVER Wind Gust: 0.84 years for cluster 8 with wind speed of 17.63 m/s
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 6.98 years for cluster 0 with wind speed of 25.64 m/s
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 9.02 years for cluster 3 with wind speed of 28.75 m/s
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.94 years for cluster 1 with wind speed of 20.26 m/s
# Return Period of Max 73_XAVER Wind Gust: 0.68 years for cluster 9 with wind speed of 15.24 m/s
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.87 years for cluster 4 with wind speed of 16.17 m/s
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.45 years for cluster 0 with wind speed of 19.57 m/s
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.17 years for cluster 2 with wind speed of 19.34 m/s
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.55 years for cluster 5 with wind speed of 13.50 m/s
# Return Period of Max 73_XAVER Wind Gust: 3.25 years for cluster 10 with wind speed of 23.33 m/s
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.73 years for cluster 1 with wind speed of 19.68 m/s
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 29.72 years for cluster 3 with wind speed of 32.04 m/s
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 1352.92 years for cluster 6 with wind speed of 46.04 m/s
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.67 years for cluster 2 with wind speed of 15.36 m/s
# Return Period of Max 73_XAVER Wind Gust: 20.65 years for cluster 11 with wind speed of 32.01 m/s
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.13 years for cluster 4 with wind speed of 17.46 m/s
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.18 years for cluster 7 with wind speed of 16.45 m/s
# Return Period of Max 73_XAVER Wind Gust: 79.37 years for cluster 12 with wind speed of 38.05 m/s
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.92 years for cluster 3 with wind speed of 26.81 m/s
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.57 years for cluster 5 with wind speed of 14.15 m/s
# Return Period of Max 73_XAVER Wind Gust: 0.66 years for cluster 13 with wind speed of 15.83 m/s
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.54 years for cluster 8 with wind speed of 12.98 m/s
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.13 years for cluster 4 with wind speed of 17.46 m/s
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 45.88 years for cluster 6 with wind speed of 38.18 m/s
# Return Period of Max 73_XAVER Wind Gust: 0.77 years for cluster 14 with wind speed of 15.50 m/s
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.35 years for cluster 5 with wind speed of 23.52 m/s
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.59 years for cluster 9 with wind speed of 13.63 m/s
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.23 years for cluster 7 with wind speed of 16.73 m/s
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.26 years for cluster 10 with wind speed of 19.36 m/s
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 19.11 years for cluster 6 with wind speed of 35.53 m/s
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.72 years for cluster 8 with wind speed of 16.53 m/s
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.44 years for cluster 7 with wind speed of 20.53 m/s
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.13 years for cluster 11 with wind speed of 22.68 m/s
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.76 years for cluster 9 with wind speed of 16.23 m/s
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.61 years for cluster 8 with wind speed of 14.93 m/s
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.07 years for cluster 12 with wind speed of 21.54 m/s
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.82 years for cluster 10 with wind speed of 22.78 m/s
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.83 years for cluster 13 with wind speed of 17.90 m/s
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.54 years for cluster 9 with wind speed of 12.00 m/s
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.01 years for cluster 11 with wind speed of 24.39 m/s
# Return Period of Max 8_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.07 years for cluster 14 with wind speed of 21.56 m/s
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.85 years for cluster 10 with wind speed of 17.28 m/s
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 3.24 years for cluster 12 with wind speed of 27.17 m/s
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.56 years for cluster 13 with wind speed of 13.81 m/s
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 1.71 years for cluster 11 with wind speed of 21.52 m/s
# Return Period of Max 83_C3S_STORM_TRACKS_ERA5 Wind Gust: 4.91 years for cluster 14 with wind speed of 25.31 m/s
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.97 years for cluster 12 with wind speed of 20.89 m/s
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 2.19 years for cluster 13 with wind speed of 23.16 m/s
# Return Period of Max 43_C3S_STORM_TRACKS_ERA5 Wind Gust: 0.54 years for cluster 14 with wind speed of 10.61 m/s

# %%
# Reset index and split 'Unnamed: 0' into 'storm_number' and 'storm_name'
log_cdf_max_all = log_cdf_max_combined.reset_index()
log_cdf_max_all[['storm_number', 'storm_name']] = log_cdf_max_all['index'].str.split('_', n=1, expand=True)

max_event_all = max_event_combined.reset_index()
max_event_all[['storm_number', 'storm_name']] = max_event_all['index'].str.split('_', n=1, expand=True)

# Drop unnecessary columns
log_cdf_max_all = log_cdf_max_all.drop(columns=['index'])

max_event_all = max_event_all.drop(columns=['index'])

# Reorder columns to place 'storm_number' and 'storm_name' at the beginning
cols = ['storm_number', 'storm_name'] + [col for col in log_cdf_max_all.columns if col not in ['storm_number', 'storm_name']]
log_cdf_max_all = log_cdf_max_all[cols]

cols = ['storm_number', 'storm_name'] + [col for col in max_event_all.columns if col not in ['storm_number', 'storm_name']]
max_event_all = max_event_all[cols]

# match the storms witht the time series 
storm_time_series = pd.read_csv('data/time_series_1h_non_EU/2m_dewpoint_temperature/2m_dewpoint_temperature_max.csv')['storm_index'].astype(int)
# Change type of 'storm_number' to integer
log_cdf_max_all['storm_number'] = log_cdf_max_all['storm_number'].astype(int)
log_cdf_max_all = log_cdf_max_all[log_cdf_max_all['storm_number'].isin(storm_time_series)]

max_event_all['storm_number'] = max_event_all['storm_number'].astype(int)
max_event_all = max_event_all[max_event_all['storm_number'].isin(storm_time_series)]

# Save the combined dataframe to multiple locations
log_cdf_max_all.to_csv(f'data/climatology_dm_winter_per_cluster{without_storms}/GEV_CDF_max/log_cdf_max_combined.csv', index=False)
log_cdf_max_all.to_csv(f'pre_processing/nestedMLR/log_cdf_max_combined{without_storms}.csv', index=False)

max_event_all.to_csv(f'data/climatology_dm_winter_per_cluster{without_storms}/EVENT_max/max_event_combined.csv', index=False)
max_event_all.to_csv(f'pre_processing/nestedMLR/max_event_combined{without_storms}.csv', index=False)
'''
# Load storm splits for training, validation, and testing
storm_training_test_valid = pd.read_csv(
    'pre_processing/time_series_i10fg_before_eu/storm_training_test_valid.csv'
)

# Filter and save data for training, validation, and testing
for split, split_name in zip(
    ['training', 'validation', 'test'],
    ['log_cdf_max_training', 'log_cdf_max_validation', 'log_cdf_max_test']
):
    split_df = log_cdf_max_all[log_cdf_max_all['storm_number'].isin(storm_training_test_valid[split])]
    split_df = split_df.drop(columns=['storm_name'])
    
    # Save the split data to multiple locations
    split_df.to_csv(f'data/climatology_dm_winter_per_cluster{without_storms}/GEV_CDF_max/{split_name}.csv', index=False)
    split_df.to_csv(f'pre_processing/nestedMLR/{split_name}{without_storms}.csv', index=False)'''
# Out:
# "\n# Load storm splits for training, validation, and testing\nstorm_training_test_valid = pd.read_csv(\n    'pre_processing/time_series_i10fg_before_eu/storm_training_test_valid.csv'\n)\n\n# Filter and save data for training, validation, and testing\nfor split, split_name in zip(\n    ['training', 'validation', 'test'],\n    ['log_cdf_max_training', 'log_cdf_max_validation', 'log_cdf_max_test']\n):\n    split_df = log_cdf_max_all[log_cdf_max_all['storm_number'].isin(storm_training_test_valid[split])]\n    split_df = split_df.drop(columns=['storm_name'])\n    \n    # Save the split data to multiple locations\n    split_df.to_csv(f'data/climatology_dm_winter_per_cluster{without_storms}/GEV_CDF_max/{split_name}.csv', index=False)\n    split_df.to_csv(f'pre_processing/nestedMLR/{split_name}{without_storms}.csv', index=False)"
