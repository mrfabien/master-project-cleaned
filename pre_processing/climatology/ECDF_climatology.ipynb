# %%
import os
import sys
import glob
import xarray as xr
import numpy as np
from scipy.stats import genextreme, weibull_min
from joblib import Parallel, delayed
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.distributions.empirical_distribution import ECDF

operating_system = 'mac'

if operating_system == 'win':
    os.chdir('C:/Users/fabau/OneDrive/Documents/GitHub/master-project-cleaned/')
elif operating_system == 'curnagl':
    os.chdir('/work/FAC/FGSE/IDYST/tbeucler/default/fabien/repos/cleaner_version/')
else:
    os.chdir('/Users/fabienaugsburger/Documents/GitHub/master-project-cleaned/')

# Add the path to the custom library
custom_library_path = os.path.abspath('util/processing/')
sys.path.append(custom_library_path)

import time_series

custom_library_path_2 = os.path.abspath('util/gev')
sys.path.append(custom_library_path_2)

import data_processing
from data_processing import depickle, save_to_pickle

# %%
# Prepare data for processing
tif_15 = xr.open_dataset('pre_processing/cluster/number_of_clusters/cleaned_cluster_15_v2.tif', engine='rasterio')
tif_15 = tif_15.rename({'x': 'longitude', 'y': 'latitude'})

path = '/Users/fabienaugsburger/Documents/GitHub/master-project-cleaned/data/time_series_rasters_storms_15h/'
cluster_csv = 'pre_processing/cluster/number_of_clusters/cleaned_cluster_15_v2.csv'
months = [10, 11, 12, 1, 2, 3]  # Winter months
days = range(1, 32)  # Days from 01 to 31
without_storms = ''

def initialize_datasets_winter(months, days):
    datasets_winter = []
    for month in months:
        for day in days:
            try:
                dataset = depickle(f'data/climatology/daily_winter_season{without_storms}/climatology_europe_winter_{month}_{day}.pkl')
                datasets_winter.append(dataset)
            except FileNotFoundError:
                print(f'No data for month {month} and day {day}')
    return datasets_winter

def initialize_datasets_winter_per_month(month, days):
    datasets_winter = []
    for day in days:
        try:
            dataset = depickle(f'data/climatology/daily_winter_season{without_storms}/climatology_europe_winter_{month}_{day}.pkl')
            datasets_winter.append(dataset)
        except FileNotFoundError:
            print(f'No data for month {month} and day {day}')
    return datasets_winter

# %% [markdown]
# # For hourly maximum

# %%
#def process_storm_file(event, cluster_data_original, datasets_winter, tif_15):
#print(f"Processing event: {event}")

# TAKES 17 MINUTES TO RUN
without_storms = '_no_storms'

# Load cluster data
cluster_data_original = pd.read_csv(cluster_csv)

# Initialize datasets_winter
datasets_winter = initialize_datasets_winter(months, days)

hourly = 'yes'
hours = range(0, 24)

clusters = range(0, 15)

for cluster_n in clusters:
    dataset_wind_speed = []
    for dataset in datasets_winter:
        for ds in dataset:
            ds_cluster = ds.where(tif_15['band_data'] == cluster_n)
            if hourly == 'yes':
                for hour in hours:
                    ds_hour = ds_cluster.sel(time=ds_cluster['time.hour'] == hour)
                    hourly_max = ds_hour['i10fg'].max().values
                    dataset_wind_speed.append(hourly_max)
            else:
                daily_max = ds_cluster['i10fg'].max().values
                dataset_wind_speed.append(daily_max)
    dataset_wind_speed = np.array(dataset_wind_speed)
    
    # plot the cdf
    dataset_wind_speed.sort()
    ecdf_x = ECDF(dataset_wind_speed).x
    ecdf_y = ECDF(dataset_wind_speed).y
    ecdf_x = ecdf_x[1:]
    ecdf_y = ecdf_y[1:]

    # save the ECDF
    pd.DataFrame(ecdf_y).to_csv(f'data/climatology_hm_winter_per_cluster{without_storms}/ECDF/ECDF_cluster_{cluster_n}.csv')

    # save the dataset_wind_speed
    pd.DataFrame(dataset_wind_speed).to_csv(f'data/climatology_hm_winter_per_cluster{without_storms}/wind_data_cluster_{cluster_n}.csv')

    print(f'Cluster {cluster_n} done')

    plt.plot(ecdf_x, ecdf_y, label=f'Cluster {cluster_n}')

plt.legend()
plt.title('CDF of daily max wind speed for each cluster')
plt.xlabel('Wind speed [m/s]')
plt.ylabel('Probability')
plt.show()

# %% [markdown]
# # For daily maximum

# %%
# TAKES 17 MINUTES TO RUN
without_storms = '_no_storms'

# Load cluster data
cluster_data_original = pd.read_csv(cluster_csv)

# Initialize datasets_winter
datasets_winter = initialize_datasets_winter(months, days)

#def process_storm_file(event, cluster_data_original, datasets_winter, tif_15):
#print(f"Processing event: {event}")

clusters = range(0, 15)

for cluster_n in clusters:
    dataset_wind_speed = []
    for dataset in datasets_winter:
        for ds in dataset:
            ds_cluster = ds.where(tif_15['band_data'] == cluster_n)
            daily_max = ds_cluster['i10fg'].max().values
            dataset_wind_speed.append(daily_max)
    dataset_wind_speed = np.array(dataset_wind_speed)
    
    # plot the cdf
    dataset_wind_speed.sort()
    ecdf_x = ECDF(dataset_wind_speed).x
    ecdf_y = ECDF(dataset_wind_speed).y
    ecdf_x = ecdf_x[1:]
    ecdf_y = ecdf_y[1:]

    # save the ECDF
    pd.DataFrame(ecdf_y).to_csv(f'data/climatology_dm_winter_per_cluster{without_storms}/ECDF/ECDF_cluster_{cluster_n}.csv')

    # save the dataset_wind_speed
    pd.DataFrame(dataset_wind_speed).to_csv(f'data/climatology_dm_winter_per_cluster{without_storms}/wind_data_cluster_{cluster_n}.csv')

    plt.plot(ecdf_x, ecdf_y, label=f'Cluster {cluster_n}')

plt.legend()
plt.title('CDF of daily max wind speed for each cluster')
plt.xlabel('Wind speed [m/s]')
plt.ylabel('Probability')
plt.show()
# Out:
# No data for month 11 and day 31
# No data for month 2 and day 30
# No data for month 2 and day 31

# %% [markdown]
# # For monthly maximum

# %%
# TAKES 17 MINUTES TO RUN
without_storms = ''

# Load cluster data
cluster_data_original = pd.read_csv(cluster_csv)

# Initialize datasets_winter (unchanged)
for m in months:
    locals()[f'datasets_winter_{m}'] = initialize_datasets_winter_per_month(m, days)
#datasets_winter = initialize_datasets_winter(months, days)

# Process data for clusters
clusters = range(0, 15)
for cluster_n in clusters:
    dataset_wind_speed = []
    for m in [10,11,12,1,2,3]:
        datasets_winter = locals()[f'datasets_winter_{m}']
        for dataset in datasets_winter:
            daily_maximum = []
            for ds in dataset:
                ds_cluster = ds.where(tif_15['band_data'] == cluster_n)
                daily_max = ds_cluster['i10fg'].max().values
                daily_maximum.append(daily_max)
            monthly_max = max(daily_maximum)
            dataset_wind_speed.append(monthly_max)
    dataset_wind_speed = np.array(dataset_wind_speed)
    
    # plot the cdf
    dataset_wind_speed.sort()
    ecdf_x = ECDF(dataset_wind_speed).x
    ecdf_y = ECDF(dataset_wind_speed).y
    ecdf_x = ecdf_x[1:]
    ecdf_y = ecdf_y[1:]

    # save the ECDF
    pd.DataFrame(ecdf_y).to_csv(f'data/climatology_mm_winter_per_cluster{without_storms}/ECDF/ECDF_cluster_{cluster_n}.csv')

    # save the dataset_wind_speed
    pd.DataFrame(dataset_wind_speed).to_csv(f'data/climatology_mm_winter_per_cluster{without_storms}/wind_data_cluster_{cluster_n}.csv')

    plt.plot(ecdf_x, ecdf_y, label=f'Cluster {cluster_n}')

plt.legend()
plt.title('CDF of daily max wind speed for each cluster')
plt.xlabel('Wind speed [m/s]')
plt.ylabel('Probability')
plt.show()
# Out:
# No data for month 11 and day 31
# No data for month 2 and day 30
# No data for month 2 and day 31
# "\n# Dictionary to store monthly max wind speed for each cluster\nmonthly_max_wind_speed = {cluster_n: [] for cluster_n in clusters}\n\nfor cluster_n in clusters:\n    # Dictionary to accumulate daily max values by month\n    monthly_data = {}\n\n    #for dataset in datasets_winter:\n    for dataset_index, dataset in enumerate(datasets_winter):\n        for ds_index, ds in enumerate(dataset):\n            # Extract the corresponding file name from initialization\n            # Assuming file names are stored in the order of initialization\n            try:\n                file_name = f'data/climatology/daily_winter_season{without_storms}/climatology_europe_winter_{months[dataset_index]}_{days[ds_index]}.pkl'\n            except:\n                print(f'No data for month {dataset_index} and day {ds_index}')\n                continue\n            \n            # Extract month and day from the file name before the .pkl extension\n            file_parts = file_name.split('_')\n            month = int(file_parts[-2])  # Second to last part is the month\n            day = int(file_parts[-1].split('.')[0])  # Last part before .pkl is the day\n            \n            # Filter data for the current cluster\n            ds_cluster = ds.where(tif_15['band_data'] == cluster_n)\n            \n            # Calculate the daily maximum wind speed\n            daily_max = ds_cluster['i10fg'].max().values\n            \n            # Accumulate daily max into monthly data\n            if month not in monthly_data:\n                monthly_data[month] = []\n            monthly_data[month].append(daily_max)\n    \n    # Compute the monthly max from the accumulated data\n    for month, daily_values in monthly_data.items():\n        monthly_max = max(daily_values)\n        monthly_max_wind_speed[cluster_n].append((month, monthly_max))\n    \n    # Save the monthly max data for the current cluster\n    monthly_data_frame = pd.DataFrame(monthly_max_wind_speed[cluster_n], columns=['Month', 'Max Wind Speed'])\n    monthly_data_frame.to_csv(f'data/climatology_mm_winter_per_cluster{without_storms}/monthly_max_wind_cluster_{cluster_n}.csv')\n\n    # Plot the monthly max wind speeds for this cluster\n    plt.plot(monthly_data_frame['Month'], monthly_data_frame['Max Wind Speed'], label=f'Cluster {cluster_n}')\n\nplt.legend()\nplt.title('Monthly Max Wind Speed for Each Cluster')\nplt.xlabel('Month')\nplt.ylabel('Wind Speed [m/s]')\nplt.show()"
